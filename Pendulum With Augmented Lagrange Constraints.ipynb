# %%
using RigidBodyDynamics
using ForwardDiff
using Plots

# %%
struct Model
    f::Function # continuous dynamics (ie, differential equation)
    n::Int # number of states
    m::Int # number of controls

    function Model(f::Function, n::Int64, m::Int64)
        # construct a model from an explicit differential equation
        new(f,n,m)
    end

    function Model(mech::Mechanism)
        # fully actuated
        m = length(joints(mech))-1  # subtract off joint to world
        Model(mech,ones(m,1))
    end

    function Model(mech::Mechanism,torques::Array)

        # construct a model using robot dynamics equation assembed from URDF file
        n = num_positions(mech) + num_velocities(mech) + num_additional_states(mech)
        num_joints = length(joints(mech))-1  # subtract off joint to world
        m = num_joints # Default to number of joints

        function fc(x,u)
            state = MechanismState{eltype(x)}(mech)

            # set the state variables:
            q = x[1:num_joints]
            qd = x[(1:num_joints)+num_joints]
            set_configuration!(state, q)
            set_velocity!(state, qd)

            [qd; Array(mass_matrix(state))\(torques.*u) - Array(mass_matrix(state))\Array(dynamics_bias(state))]
        end
        new(fc, n, convert(Int,sum(torques)))
    end
end

function Model(urdf::String)
    # construct modeling using string to urdf file
    mech = parse_urdf(Float64,urdf)
    Model(mech)
end

function Model(urdf::String,torques::Array{Float64,1})
    # underactuated system (potentially)
    # construct modeling using string to urdf file
    mech = parse_urdf(Float64,urdf)
    Model(mech,torques)
end
# Out:
# Model

# %%
# cost function
struct Objective
    Q::Array{Float64,2}
    R::Array{Float64,2}
    Qf::Array{Float64,2}
    tf::Float64
    x0::Array{Float64,1}
    xf::Array{Float64,1}
end

# %%
struct Solver
    model::Model
    obj::Objective
    dt::Float64
    fd::Function  # discrete dynamics
    F::Function
    N::Int

    function Solver(model::Model, obj::Objective, discretizer::Function=rk4; dt=0.01)
        fd = discretizer(model.f, dt)     # Discrete dynamics
        f_aug = f_augmented(model)  # Augmented continuous dynamics
        fd_aug = discretizer(f_aug)  # Augmented discrete dynamics
        F(S) = ForwardDiff.jacobian(fd_aug, S)

        function Jacobians(x::Array,u::Array)
            F_aug = F([x;u;dt])
            fx = F_aug[1:model.n,1:model.n]
            fu = F_aug[1:model.n,model.n+1:model.n+model.m]
            return fx, fu
        end

        N = Int(floor(obj.tf/dt));
        new(model, obj, dt, fd, Jacobians, N)
    end
end

# Midpoint Integrator
function f_midpoint(f::Function, dt::Float64)
    dynamics_midpoint(x,u)  = x + f(x + f(x,u)*dt/2, u)*dt
end

function f_midpoint(f::Function)
    dynamics_midpoint(S::Array)  = S + f(S + f(S)*S[end]/2)*S[end]
end

# RK4 Integrator
function rk4(f::Function,dt::Float64)
    # Runge-Kutta 4
    k1(x,u) = dt*f(x,u)
    k2(x,u) = dt*f(x + k1(x,u)/2.,u)
    k3(x,u) = dt*f(x + k2(x,u)/2.,u)
    k4(x,u) = dt*f(x + k3(x,u), u)
    fd(x,u) = x + (k1(x,u) + 2.*k2(x,u) + 2.*k3(x,u) + k4(x,u))/6.
end

function rk4(f_aug::Function)
    # Runge-Kutta 4
    fd(S::Array) = begin
        k1(S) = S[end]*f_aug(S)
        k2(S) = S[end]*f_aug(S + k1(S)/2.)
        k3(S) = S[end]*f_aug(S + k2(S)/2.)
        k4(S) = S[end]*f_aug(S + k3(S))
        S + (k1(S) + 2.*k2(S) + 2.*k3(S) + k4(S))/6.
    end
end

# Assembled augmented function
function f_augmented(model::Model)
    f_aug = f_augmented(model.f, model.n, model.m)
    f(S::Array) = [f_aug(S); zeros(model.m+1,1)]
end

function f_augmented(f::Function, n::Int, m::Int)
    f_aug(S::Array) = f(S[1:n], S[n+(1:m)])
end
# Out:
# f_augmented (generic function with 2 methods)

# %%
#iLQR
function rollout!(solver::Solver,X::Array{Float64,2},U::Array{Float64,2})
    X[:,1] = solver.obj.x0
    for k = 1:solver.N-1
        X[:,k+1] = solver.fd(X[:,k],U[:,k])
    end
end

function rollout!(solver::Solver, X::Array{Float64,2}, U::Array{Float64,2}, K::Array{Float64,3}, d::Array{Float64,2}, alpha::Float64, X_::Array{Float64,2}, U_::Array{Float64,2})
    N = solver.N
    X_[:,1] = solver.obj.x0;
    for k = 2:N
        a = alpha*(d[:,k-1]);
        delta = (X_[:,k-1] - X[:,k-1])

        U_[:, k-1] = U[:, k-1] - K[:,:,k-1]*delta - a;
        X_[:,k] = solver.fd(X_[:,k-1], U_[:,k-1]);
    end
end

function rollout!(solver::Solver, X::Array{Float64,2}, U::Array{Float64,2}, K::Array{Float64,3}, d::Array{Float64,2}, alpha::Float64)
    N = solver.N
    X_ = zeros(solver.model.n, N);
    U_ = zeros(solver.model.m, N)
    rollout!(solver::Solver, X::Array{Float64,2}, U::Array{Float64,2}, K::Array{Float64,3}, d::Array{Float64,2},
        alpha::Float64, X_::Array{Float64,2}, U_::Array{Float64,2})
    return X_, U_
end

function cost(solver::Solver,X::Array{Float64,2},U::Array{Float64,2})
    N = solver.N
    Q = solver.obj.Q
    R = solver.obj.R
    xf = solver.obj.xf
    Qf = solver.obj.Qf

    J = 0.0
    for k = 1:N-1
      J += 0.5*(X[:,k] - xf)'*Q*(X[:,k] - xf) + 0.5*U[:,k]'*R*U[:,k]
    end
    J += 0.5*(X[:,N] - xf)'*Qf*(X[:,N] - xf)
    return J
end

# overloaded cost function to accomodate Augmented Lagrance method
function cost(solver::Solver,X::Array{Float64,2},U::Array{Float64,2},C::Array{Float64,2},I_mu::Array{Float64,3},LAMBDA::Array{Float64,2})
    J = cost(solver,X,U)
    for k = 1:solver.N
        J += 0.5*(C[:,k]'*I_mu[:,:,k]*C[:,k] + LAMBDA[:,k]'*C[:,k])
    end
    return J
end

function backwardpass(solver::Solver,X::Array{Float64,2},U::Array{Float64,2},K::Array{Float64,3},d::Array{Float64,2},C::Array{Float64,2},Cx::Array{Float64,3},Cu::Array{Float64,3},I_mu::Array{Float64,3},LAMBDA::Array{Float64,2})
    N = solver.N
    n = solver.model.n
    m = solver.model.m
    Q = solver.obj.Q
    R = solver.obj.R
    xf = solver.obj.xf
    Qf = solver.obj.Qf

    S = Qf
    s = Qf*(X[:,N] - xf)
    v1 = 0.
    v2 = 0.

    mu = 0.
    k = N-1
    while k >= 1
        lx = Q*(X[:,k] - xf)
        lu = R*(U[:,k])
        lxx = Q
        luu = R
        fx, fu = solver.F(X[:,k],U[:,k])
        Qx = lx + fx'*s 
        Qu = lu + fu'*s 
        Qxx = lxx + fx'*S*fx
        Quu = luu + fu'*(S + mu*eye(n))*fu
        Qux = fu'*(S + mu*eye(n))*fx

        # regularization
        if any(eigvals(Quu).<0.)
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end
        
        # Constraints
        Qx += Cx[:,:,k]'*I_mu[:,:,k]*C[:,k] + Cx[:,:,k]'*LAMBDA[:,k]
        Qu += Cu[:,:,k]'*I_mu[:,:,k]*C[:,k] + Cu[:,:,k]'*LAMBDA[:,k]
        Qxx += Cx[:,:,k]'*I_mu[:,:,k]*Cx[:,:,k]
        Quu += Cu[:,:,k]'*I_mu[:,:,k]*Cu[:,:,k]
        Qux += Cu[:,:,k]'*I_mu[:,:,k]*Cx[:,:,k]
        
        K[:,:,k] = Quu\Qux
        d[:,k] = Quu\Qu
        s = (Qx' - Qu'*K[:,:,k] + d[:,k]'*Quu*K[:,:,k] - d[:,k]'*Qux)'
        S = Qxx + K[:,:,k]'*Quu*K[:,:,k] - K[:,:,k]'*Qux - Qux'*K[:,:,k]

        # terms for line search
        v1 += float(d[:,k]'*Qu)[1]
        v2 += float(d[:,k]'*Quu*d[:,k])

        k = k - 1;
    end
    return K, d, v1, v2
end


function backwardpass(solver::Solver,X::Array{Float64,2},U::Array{Float64,2},K::Array{Float64,3},d::Array{Float64,2})
    N = solver.N
    n = solver.model.n
    m = solver.model.m
    Q = solver.obj.Q
    R = solver.obj.R
    xf = solver.obj.xf
    Qf = solver.obj.Qf

    S = Qf
    s = Qf*(X[:,N] - xf)
    v1 = 0.
    v2 = 0.

    mu = 0.
    k = N-1
    while k >= 1
        lx = Q*(X[:,k] - xf)
        lu = R*(U[:,k])
        lxx = Q
        luu = R
        fx, fu = solver.F(X[:,k],U[:,k])
        Qx = lx + fx'*s
        Qu = lu + fu'*s
        Qxx = lxx + fx'*S*fx
        Quu = luu + fu'*(S + mu*eye(n))*fu
        Qux = fu'*(S + mu*eye(n))*fx

        # regularization
        if any(eigvals(Quu).<0.)
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end

        K[:,:,k] = Quu\Qux
        d[:,k] = Quu\Qu
        s = (Qx' - Qu'*K[:,:,k] + d[:,k]'*Quu*K[:,:,k] - d[:,k]'*Qux)'
        S = Qxx + K[:,:,k]'*Quu*K[:,:,k] - K[:,:,k]'*Qux - Qux'*K[:,:,k]

        # terms for line search
        v1 += float(d[:,k]'*Qu)[1]
        v2 += float(d[:,k]'*Quu*d[:,k])

        k = k - 1;
    end
    return K, d, v1, v2
end

function forwardpass!(X_, U_, solver::Solver, X::Array{Float64,2}, U::Array{Float64,2}, K::Array{Float64,3}, d::Array{Float64,2}, v1::Float64, v2::Float64, C_function::Function,I_mu_function::Function,LAMBDA::Array{Float64,2},MU::Array{Float64,2}, c1::Float64=0.5, c2::Float64=0.9)

    # Compute original cost
    J_prev = cost(solver, X, U, C_function(X,U), I_mu_function(X,U,LAMBDA,MU), LAMBDA)

    J = Inf
    alpha = 1.0
    iter = 0
    dV = Inf
    z = 0.

    while z < c1 || z > c2
        rollout!(solver, X, U, K, d, alpha, X_, U_)

        # Calcuate cost
        
        J = cost(solver, X_, U_, C_function(X_,U_), I_mu_function(X_,U_,LAMBDA,MU), LAMBDA)

        dV = alpha*v1 + (alpha^2)*v2/2.
        z = (J_prev - J)/dV[1,1]
        alpha = alpha/2.
        iter = iter + 1

        if iter > 25
            println("max iterations (forward pass)")
            break
        end
        iter += 1
    end

    println("New cost: $J")
    println("- Expected improvement: $(dV[1])")
    println("- Actual improvement: $(J_prev-J)")
    println("- (z = $z)\n")

    return J

end

function solve(solver::Solver)
    U = zeros(solver.model.m, solver.N)
    solve(solver,U)
end
# Out:
# solve (generic function with 4 methods)

# %%
function solve(solver::Solver,U::Array{Float64,2},iterations::Int64=100,eps::Float64=1e-5)
    N = solver.N
    n = solver.model.n
    m = solver.model.m
    X = zeros(n,N)
    X_ = similar(X)
    U_ = similar(U)
    K = zeros(m,n,N-1)
    d = zeros(m,N-1)
    J = 0.

    ### Constraints
    p = 2*m + n
    LAMBDA = zeros(p,N)
    MU = ones(p,N)
    u_min = -2.
    u_max = 2.
    xf = solver.obj.xf
    
    
    function control_constraints(X,U)
        c = zeros(2*size(U,1),N)

        for i = 1:N-1
            c[:,i] = [u_max - U[:,i]; U[:,i] - u_min]
        end

        return c
    end

    function control_constraints_derivatives(X,U)
        c = zeros(2*size(U,1),size(U,1),N)

        for i = 1:N-1
            c[:,:,i] = [-eye(size(U,1)); eye(size(U,1))]
        end

        return c
    end

    function terminal_state_constraints(X,U)
        c = zeros(size(X,1),N)
        c[:,N] = X[:,end] - xf
        return c
    end

    function terminal_state_constraints_derivatives(X,U)
        c = zeros(size(X,1),size(X,1),N)
        c[:,:,N] = eye(size(X,1))
        return c
    end

    function C(X,U)
        return [control_constraints(X,U); terminal_state_constraints(X,U)]
    end

    function Cx(X,U)
        return [zeros(2*size(U,1),size(X,1),N); terminal_state_constraints_derivatives(X,U)]
    end

    function Cu(X,U)
        return [control_constraints_derivatives(X,U); zeros(size(X,1),size(U,1),N)]
    end

    function I_mu(X,U,LAMBDA,MU)
        I = zeros(size(U,1)*2 + size(X,1),size(U,1)*2 + size(X,1),N)
        m = 2*size(U,1) # number of inequality constraints
        c = C(X,U)
        for k = 1:N
            # inequality constraints (controls)
            for j = 1:m
                if c[j,k] < 0. || LAMBDA[j,k] > 0.
                    I[j,j,k] = MU[j,k]
                end
            end

            # equality constraints (terminal state constraint)
            for j = m+1:m+size(X,1)
                if k == N
                    I[j,j,k] = MU[j,k]
                end
            end

        end
        return I
    end  
    
    ### SOLVER
    
    # initial roll-out
    X[:,1] = solver.obj.x0
    rollout!(solver, X, U)
    
    for k = 1:10
                
        J_prev = cost(solver, X, U, C(X,U), I_mu(X,U,LAMBDA,MU), LAMBDA)
        println("Cost ($k): $J_prev\n")

        for i = 1:iterations
            println("--Iteration: $k-($i)--")
            K, d, v1, v2 = backwardpass(solver,X,U,K,d, C(X,U), Cx(X,U), Cu(X,U), I_mu(X,U,LAMBDA,MU), LAMBDA)
            J = forwardpass!(X_, U_, solver, X, U, K, d, v1, v2, C, I_mu, LAMBDA, MU)
            X = copy(X_)
            U = copy(U_)
            dJ = copy(abs(J-J_prev))
            J_prev = copy(J)
            
            if dJ < eps
                println("   eps criteria met at iteration: $i\n")
                break
            end
        end
        
        # Outer Loop - update lambda, mu
        println("Constraint update")
        c = C(X,U)
        for jj = 1:N
            for ii = 1:p
                LAMBDA[ii,jj] += -MU[ii,jj]*min(c[ii,jj],0)
                MU[ii,jj] += 10.0
            end
        end
    end  

    return X, U
    
end
# Out:
# solve (generic function with 4 methods)

# %%
## Simple Pendulum
# https://github.com/HarvardAgileRoboticsLab/unscented-dynamic-programming/blob/master/pendulum_dynamics.m
function pendulum_dynamics(x,u)
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (u - m*g*lc*sin(x[1]) - b*x[2])];
end
model = Model(pendulum_dynamics,2,1)

x0 = [0.; 0.]
xf = [pi; 0.] # (ie, swing up)

#costs
Q = 1e-3*eye(model.n)
Qf = 100.0*eye(model.n)
R = 1e-3*eye(model.m)

#simulation
dt = 0.1
tf = 5.0

obj = Objective(Q,R,Qf,tf,x0,xf)
solver = Solver(model,obj,dt=dt) 

# run solver
U = 1.*rand(solver.model.m,solver.N-1)
X_pendulum, U_pendulum = @time solve(solver,U);
# Out:
# Cost (1): 458.6713282179907
#
# --Iteration: 1-(1)--
# New cost: 113.44852790519803
# - Expected improvement: 567.0317281715935
# - Actual improvement: 345.2228003127927
# - (z = 0.6088244857584448)
#
# --Iteration: 1-(2)--
# New cost: 31.672515195339734
# - Expected improvement: 139.85040956692978
# - Actual improvement: 81.77601270985829
# - (z = 0.5847391721131987)
#
# --Iteration: 1-(3)--
# New cost: 18.176220363398084
# - Expected improvement: 17.41769346972671
# - Actual improvement: 13.49629483194165
# - (z = 0.774861198206252)
#
# --Iteration: 1-(4)--
# New cost: 9.842658989811014
# - Expected improvement: 9.900112658514889
# - Actual improvement: 8.33356137358707
# - (z = 0.8417642971385322)
#
# --Iteration: 1-(5)--
# New cost: 5.79231911617169
# - Expected improvement: 5.260297614503766
# - Actual improvement: 4.050339873639324
# - (z = 0.7699830257648674)
#
# --Iteration: 1-(6)--
# New cost: 3.5738647075213654
# - Expected improvement: 3.011844211824143
# - Actual improvement: 2.2184544086503246
# - (z = 0.7365767458824516)
#
# --Iteration: 1-(7)--
# New cost: 2.2420622040570177
# - Expected improvement: 1.7802353800680444
# - Actual improvement: 1.3318025034643477
# - (z = 0.7481047272599668)
#
# --Iteration: 1-(8)--
# New cost: 0.9723447233732256
# - Expected improvement: 2.3155182846916795
# - Actual improvement: 1.269717480683792
# - (z = 0.5483513082484079)
#
# --Iteration: 1-(9)--
# New cost: 0.7147831695276072
# - Expected improvement: 0.34266044342219293
# - Actual improvement: 0.2575615538456184
# - (z = 0.7516524267386069)
#
# --Iteration: 1-(10)--
# New cost: 0.45573273446496154
# - Expected improvement: 0.44451998691908423
# - Actual improvement: 0.2590504350626457
# - (z = 0.5827644260904753)
#
# --Iteration: 1-(11)--
# New cost: 0.3819382079098729
# - Expected improvement: 0.12944354235613237
# - Actual improvement: 0.07379452655508867
# - (z = 0.5700904441571988)
#
# --Iteration: 1-(12)--
# New cost: 0.36592579668240666
# - Expected improvement: 0.02084819071254434
# - Actual improvement: 0.016012411227466217
# - (z = 0.7680480022581319)
#
# --Iteration: 1-(13)--
# New cost: 0.3628410475248196
# - Expected improvement: 0.005983638248897814
# - Actual improvement: 0.0030847491575870523
# - (z = 0.5155306904048323)
#
# --Iteration: 1-(14)--
# New cost: 0.3482741976070302
# - Expected improvement: 0.024732716454261405
# - Actual improvement: 0.014566849917789393
# - (z = 0.5889708857790892)
#
# --Iteration: 1-(15)--
# New cost: 0.34261397262924614
# - Expected improvement: 0.008925698551413088
# - Actual improvement: 0.005660224977784067
# - (z = 0.6341492427937708)
#
# --Iteration: 1-(16)--
# New cost: 0.3403838358372729
# - Expected improvement: 0.003410300385499397
# - Actual improvement: 0.0022301367919732584
# - (z = 0.6539414537956257)
#
# --Iteration: 1-(17)--
# New cost: 0.3383848404616097
# - Expected improvement: 0.0028355415178167014
# - Actual improvement: 0.0019989953756631706
# - (z = 0.7049783482635616)
#
# --Iteration: 1-(18)--
# New cost: 0.33756007331114274
# - Expected improvement: 0.0014527463066086714
# - Actual improvement: 0.0008247671504669762
# - (z = 0.5677296488141375)
#
# --Iteration: 1-(19)--
# New cost: 0.33568576663771377
# - Expected improvement: 0.0027391358658969
# - Actual improvement: 0.0018743066734289715
# - (z = 0.6842693335386086)
#
# --Iteration: 1-(20)--
# New cost: 0.334920888414778
# - Expected improvement: 0.000906854057211174
# - Actual improvement: 0.0007648782229357498
# - (z = 0.8434413639698113)
#
# --Iteration: 1-(21)--
# max iterations (forward pass)
# New cost: 0.334920570966472
# - Expected improvement: 3.1747612535600216e-7
# - Actual improvement: 3.1744830603086527e-7
# - (z = 0.9999123734891696)
#
#    eps criteria met at iteration: 21
#
# Constraint update
# Cost (2): 0.3373230676870532
#
# --Iteration: 2-(1)--
# New cost: 0.3365599727557918
# - Expected improvement: 0.0008827733631630853
# - Actual improvement: 0.000763094931261421
# - (z = 0.8644290404585365)
#
# --Iteration: 2-(2)--
# New cost: 0.3352842839585399
# - Expected improvement: 0.0015183387991275252
# - Actual improvement: 0.0012756887972519282
# - (z = 0.8401871821921236)
#
# --Iteration: 2-(3)--
# max iterations (forward pass)
# New cost: 0.3352838196661062
# - Expected improvement: 4.464830542824936e-7
# - Actual improvement: 4.6429243366619133e-7
# - (z = 1.0398881418071235)
#
#    eps criteria met at iteration: 3
#
# Constraint update
# Cost (3): 0.335145902320768
#
# --Iteration: 3-(1)--
# max iterations (forward pass)
# New cost: 0.33514551359204503
# - Expected improvement: 3.14045584148473e-7
# - Actual improvement: 3.887287229886738e-7
# - (z = 1.2378098677703184)
#
#    eps criteria met at iteration: 1
#
# Constraint update
# Cost (4): 0.3336235567488589
#
# --Iteration: 4-(1)--
# New cost: 0.33353598575735444
# - Expected improvement: 0.00012452932884274447
# - Actual improvement: 8.75709915044709e-5
# - (z = 0.7032157991878)
#
# --Iteration: 4-(2)--
# New cost: 0.3334930007434877
# - Expected improvement: 5.921552087157666e-5
# - Actual improvement: 4.298501386673648e-5
# - (z = 0.7259078909389313)
#
# --Iteration: 4-(3)--
# New cost: 0.3334876632533685
# - Expected improvement: 7.183463312548772e-6
# - Actual improvement: 5.3374901192171365e-6
# - (z = 0.7430246229410109)
#
#    eps criteria met at iteration: 3
#
# Constraint update
# Cost (5): 0.33051951267118795
#
# --Iteration: 5-(1)--
# max iterations (forward pass)
# New cost: 0.3305194598040971
# - Expected improvement: 7.005445255654992e-7
# - Actual improvement: 5.286709087171104e-8
# - (z = 0.07546571123232353)
#
#    eps criteria met at iteration: 1
#
# Constraint update
# Cost (6): 0.3261370401334059
#
# --Iteration: 6-(1)--
# max iterations (forward pass)
# New cost: 0.3261367310906435
# - Expected improvement: 2.261719069998577e-6
# - Actual improvement: 3.0904276238086226e-7
# - (z = 0.13664064935396983)
#
#    eps criteria met at iteration: 1
#
# Constraint update
# Cost (7): 0.3203389426103261
#
# --Iteration: 7-(1)--
# max iterations (forward pass)
# New cost: 0.32033774948855415
# - Expected improvement: 5.423542318574632e-6
# - Actual improvement: 1.1931217719363119e-6
# - (z = 0.21998939103878473)
#
#    eps criteria met at iteration: 1
#
# Constraint update
# Cost (8): 0.3131229791313539
#
# --Iteration: 8-(1)--
# max iterations (forward pass)
# New cost: 0.3131200158234241
# - Expected improvement: 1.0703111732928064e-5
# - Actual improvement: 2.963307929815251e-6
# - (z = 0.27686414976858087)
#
#    eps criteria met at iteration: 1
#
# Constraint update
# Cost (9): 0.30448613535657165
#
# --Iteration: 9-(1)--
# max iterations (forward pass)
# New cost: 0.30448026272798034
# - Expected improvement: 1.8618494987423175e-5
# - Actual improvement: 5.872628591307993e-6
# - (z = 0.31541908168597754)
#
#    eps criteria met at iteration: 1
#
# Constraint update
# Cost (10): 0.2944246223437456
#
# --Iteration: 10-(1)--
# max iterations (forward pass)
# New cost: 0.29441445183591586
# - Expected improvement: 2.9663463369887938e-5
# - Actual improvement: 1.017050782975426e-5
# - (z = 0.34286312771146527)
#
# --Iteration: 10-(2)--
# max iterations (forward pass)
# New cost: 0.29440428615804487
# - Expected improvement: 2.9656253777726412e-5
# - Actual improvement: 1.0165677870987988e-5
# - (z = 0.3427836147876172)
#
# --Iteration: 10-(3)--
# max iterations (forward pass)
# New cost: 0.29439412530866366
# - Expected improvement: 2.9649045944118454e-5
# - Actual improvement: 1.016084938121331e-5
# - (z = 0.3427040924137709)
#
# --Iteration: 10-(4)--
# max iterations (forward pass)
# New cost: 0.29438396928630556
# - Expected improvement: 2.9641839868634078e-5
# - Actual improvement: 1.015602235809876e-5
# - (z = 0.3426245605235016)
#
# --Iteration: 10-(5)--
# max iterations (forward pass)
# New cost: 0.29437381808950297
# - Expected improvement: 2.963463555084497e-5
# - Actual improvement: 1.0151196802588025e-5
# - (z = 0.3425450191608172)
#
# --Iteration: 10-(6)--
# max iterations (forward pass)
# New cost: 0.29436367171678957
# - Expected improvement: 2.9627432990321822e-5
# - Actual improvement: 1.014637271340435e-5
# - (z = 0.3424654682948331)
#
# --Iteration: 10-(7)--
# max iterations (forward pass)
# New cost: 0.29435353016669813
# - Expected improvement: 2.9620232186635815e-5
# - Actual improvement: 1.0141550091435914e-5
# - (z = 0.3423859079677175)
#
# --Iteration: 10-(8)--
# max iterations (forward pass)
# New cost: 0.2943433934377632
# - Expected improvement: 2.9613033139357997e-5
# - Actual improvement: 1.0136728934906358e-5
# - (z = 0.3423063381317014)
#
# --Iteration: 10-(9)--
# max iterations (forward pass)
# New cost: 0.2943332615285188
# - Expected improvement: 2.9605835848060147e-5
# - Actual improvement: 1.0131909244426307e-5
# - (z = 0.34222675881958514)
#
# --Iteration: 10-(10)--
# max iterations (forward pass)
# New cost: 0.2943231344374999
# - Expected improvement: 2.959864031231312e-5
# - Actual improvement: 1.0127091018885537e-5
# - (z = 0.34214717000607076)
#
# --Iteration: 10-(11)--
# max iterations (forward pass)
# New cost: 0.2943130121632422
# - Expected improvement: 2.9591446531688976e-5
# - Actual improvement: 1.0122274257728936e-5
# - (z = 0.34206757168458)
#
# --Iteration: 10-(12)--
# max iterations (forward pass)
# New cost: 0.29430289470428117
# - Expected improvement: 2.9584254505759464e-5
# - Actual improvement: 1.0117458961012016e-5
# - (z = 0.34198796386917063)
#
# --Iteration: 10-(13)--
# max iterations (forward pass)
# New cost: 0.29429278205915194
# - Expected improvement: 2.957706423409635e-5
# - Actual improvement: 1.0112645129234377e-5
# - (z = 0.34190834658892716)
#
# --Iteration: 10-(14)--
# max iterations (forward pass)
# New cost: 0.294282674226391
# - Expected improvement: 2.95698757162709e-5
# - Actual improvement: 1.0107832760952729e-5
# - (z = 0.3418287198072621)
#
# --Iteration: 10-(15)--
# max iterations (forward pass)
# New cost: 0.29427257120453565
# - Expected improvement: 2.956268895185571e-5
# - Actual improvement: 1.0103021855334404e-5
# - (z = 0.3417490835081907)
#
# --Iteration: 10-(16)--
# max iterations (forward pass)
# New cost: 0.2942624729921225
# - Expected improvement: 2.9555503940422416e-5
# - Actual improvement: 1.009821241315656e-5
# - (z = 0.3416694377301906)
#
# --Iteration: 10-(17)--
# max iterations (forward pass)
# New cost: 0.2942523795876894
# - Expected improvement: 2.9548320681543222e-5
# - Actual improvement: 1.0093404433086928e-5
# - (z = 0.3415897824403799)
#
# --Iteration: 10-(18)--
# max iterations (forward pass)
# New cost: 0.29424229098977495
# - Expected improvement: 2.9541139174790897e-5
# - Actual improvement: 1.0088597914459374e-5
# - (z = 0.34151011762838646)
#
# --Iteration: 10-(19)--
# max iterations (forward pass)
# New cost: 0.29423220719691584
# - Expected improvement: 2.9533959419737667e-5
# - Actual improvement: 1.0083792859105767e-5
# - (z = 0.3414304433684136)
#
# --Iteration: 10-(20)--
# max iterations (forward pass)
# New cost: 0.29422212820765237
# - Expected improvement: 2.9526781415955798e-5
# - Actual improvement: 1.0078989263473392e-5
# - (z = 0.34135075955237265)
#
# --Iteration: 10-(21)--
# max iterations (forward pass)
# New cost: 0.29421205402052203
# - Expected improvement: 2.9519605163017977e-5
# - Actual improvement: 1.0074187130337808e-5
# - (z = 0.3412710662864388)
#
# --Iteration: 10-(22)--
# max iterations (forward pass)
# New cost: 0.294201984634066
# - Expected improvement: 2.9512430660496713e-5
# - Actual improvement: 1.0069386456035279e-5
# - (z = 0.3411913634587021)
#
# --Iteration: 10-(23)--
# max iterations (forward pass)
# New cost: 0.2941919200468231
# - Expected improvement: 2.9505257907965447e-5
# - Actual improvement: 1.0064587242897272e-5
# - (z = 0.341111651160323)
#
# --Iteration: 10-(24)--
# max iterations (forward pass)
# New cost: 0.29418186025733417
# - Expected improvement: 2.9498086904996428e-5
# - Actual improvement: 1.0059789488925386e-5
# - (z = 0.3410319293357782)
#
# --Iteration: 10-(25)--
# max iterations (forward pass)
# New cost: 0.2941718052641396
# - Expected improvement: 2.949091765116333e-5
# - Actual improvement: 1.005499319456371e-5
# - (z = 0.3409521980122945)
#
# --Iteration: 10-(26)--
# max iterations (forward pass)
# New cost: 0.2941617550657804
# - Expected improvement: 2.948375014603883e-5
# - Actual improvement: 1.0050198359201623e-5
# - (z = 0.3408724571813629)
#
# --Iteration: 10-(27)--
# max iterations (forward pass)
# New cost: 0.29415170966079796
# - Expected improvement: 2.9476584389196404e-5
# - Actual improvement: 1.0045404982450545e-5
# - (z = 0.34079270684198854)
#
# --Iteration: 10-(28)--
# max iterations (forward pass)
# New cost: 0.2941416690477336
# - Expected improvement: 2.9469420380208923e-5
# - Actual improvement: 1.0040613064365989e-5
# - (z = 0.3407129470082508)
#
# --Iteration: 10-(29)--
# max iterations (forward pass)
# New cost: 0.29413163322513014
# - Expected improvement: 2.9462258118649816e-5
# - Actual improvement: 1.0035822603449152e-5
# - (z = 0.34063317764147905)
#
# --Iteration: 10-(30)--
# max iterations (forward pass)
# New cost: 0.2941216021915306
# - Expected improvement: 2.9455097604093202e-5
# - Actual improvement: 1.0031033599533501e-5
# - (z = 0.34055339874818635)
#
# --Iteration: 10-(31)--
# max iterations (forward pass)
# New cost: 0.2941115759454778
# - Expected improvement: 2.9447938836112318e-5
# - Actual improvement: 1.002624605278557e-5
# - (z = 0.3404736103462114)
#
# --Iteration: 10-(32)--
# max iterations (forward pass)
# New cost: 0.29410155448551445
# - Expected improvement: 2.9440781814281404e-5
# - Actual improvement: 1.0021459963371893e-5
# - (z = 0.3403938124533972)
#
# --Iteration: 10-(33)--
# max iterations (forward pass)
# New cost: 0.2940915378101842
# - Expected improvement: 2.943362653817342e-5
# - Actual improvement: 1.0016675330237756e-5
# - (z = 0.34031400504612663)
#
# --Iteration: 10-(34)--
# max iterations (forward pass)
# New cost: 0.29408152591803216
# - Expected improvement: 2.9426473007362474e-5
# - Actual improvement: 1.0011892152050894e-5
# - (z = 0.3402341880913125)
#
# --Iteration: 10-(35)--
# max iterations (forward pass)
# New cost: 0.2940715188076025
# - Expected improvement: 2.9419321221423298e-5
# - Actual improvement: 1.0007110429643973e-5
# - (z = 0.340154361629416)
#
# --Iteration: 10-(36)--
# max iterations (forward pass)
# New cost: 0.2940615164774405
# - Expected improvement: 2.941217117992991e-5
# - Actual improvement: 1.0002330162017792e-5
# - (z = 0.3400745256386621)
#
# --Iteration: 10-(37)--
# max iterations (forward pass)
# New cost: 0.29405151892609094
# - Expected improvement: 2.940502288245634e-5
# - Actual improvement: 9.99755134956093e-6
# - (z = 0.3399946801444484)
#
#    eps criteria met at iteration: 37
#
# Constraint update
#   5.908513 seconds (23.12 M allocations: 1.038 GiB, 6.16% gc time)

# %%
println(X_pendulum[:,end])
plot(linspace(0,tf,solver.N),X_pendulum[1,:],label="theta")
plot!(linspace(0,tf,solver.N),X_pendulum[2,:],label="theta_dot",title="Pendulum",ylabel="states")
# Out:
# [3.1407, 0.000315375]

# %%
plot(U_pendulum',title="Pendulum",ylabel="Control",label="u1")

# %%
plt = plot()
anim = @animate for i=1:size(X_pendulum,2)
    x = cos(X_pendulum[1,i] - pi/2)
    y = sin(X_pendulum[1,i] - pi/2)
    plt = plot([0,x],[0,y],xlims=(-1.5,1.5),ylims=(-1.5,1.5),color="black",size=(150,150),label="")
    end every 2

gif(anim,"pendulum_constrained.gif",fps=5)
# Out:
# INFO: Saved animation to C:\Users\taylor howell\Google Drive\Stanford\Research-Manchester\iLQR (constrained)\pendulum_constrained.gif
# Plots.AnimatedGif("C:\\Users\\taylor howell\\Google Drive\\Stanford\\Research-Manchester\\iLQR (constrained)\\pendulum_constrained.gif")
