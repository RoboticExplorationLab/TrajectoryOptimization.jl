# %%
using ForwardDiff
using Plots

# %%
## Simple Pendulum
n = 2 # number of states 
m = 1 # number of controls

#initial and goal conditions
x0 = [0.; 0.]
xf = [pi; 0.] # (ie, swing up)

#costs
Q = 0.3*eye(n)
Qf = 30.0*eye(n)
R = 0.3*eye(m)

#simulation
dt = 0.1
tf = 5.
# Out:
# 5.0

# %%
# Dynamics 
function fc(x,u)
    # continuous dynamics (as defined in https://github.com/HarvardAgileRoboticsLab/unscented-dynamic-programming/blob/master/pendulum_dynamics.m)
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (u - m*g*lc*sin(x[1]) - b*x[2])];
end

function f(x,u1,u2,du,dt)
    # RK4
    k1 = dt*fc(x,u1+du)
    k2 = dt*fc(x + k1/2,(u1+u2)/2 + du)
    k3 = dt*fc(x + k2/2,(u1+u2)/2 + du)
    k4 = dt*fc(x + k3, u2 + du)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

function fc_aug(x)
    # augmented continuous dynamics
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (x[3] - m*g*lc*sin(x[1]) - b*x[2]); 0.0; 0.0]; # xd, xdd, u, dt
end

function f2_aug(x)
    # RK4
    #x[3] = x[4] + x[6] # u = u1 + du
    k1 = x[end]*fc_aug(x)
    #x[3] = (x[4]+x[5])/x[end] + x[6] # u = (u1+u2)/dt + du
    k2 = x[end]*fc_aug(x + k1/2)
    k3 = x[end]*fc_aug(x + k2/2)
    #x[3] = x[5] + x[6] # u = u2 + du
    k4 = x[end]*fc_aug(x + k3)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

F = x-> ForwardDiff.jacobian(f2_aug,x)
# Out:
# (::#47) (generic function with 1 method)

# %%
#iLQR
function rollout(x0,U,f,dt,tf)
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    X[:,1] = x0
    for k = 1:N-1
        if k == N-1
            X[:,k+1] = f(X[:,k],U[:,k],U[:,k],0.0,dt)
        else
            X[:,k+1] = f(X[:,k],U[:,k],U[:,k+1],0.0,dt)
        end
    end
    return X
end

function cost(X,U,Q,R,Qf,xf)
    N = size(X,2)
    J = 0.0
    for k = 1:N-1
      J += 0.5*(X[:,k] - xf)'*Q*(X[:,k] - xf) + 0.5*U[:,k]'*R*U[:,k]
    end
    J += 0.5*(X[:,N] - xf)'*Qf*(X[:,N] - xf)
    return J
end

function backwardpass(X,U,F,Q,R,Qf,xf)
    n, N = size(X)
    m = size(U,1)
    
    S = zeros(n,n,N)
    s = zeros(n,N)
    
    Qx = zeros(n,1,N)
    Qu = zeros(m,1,N)
    Qxx = zeros(n,n,N)
    Quu = zeros(m,m,N)
    Qux = zeros(m,n,N)
    
    K = zeros(m,n,N-1)
    l = zeros(m,N-1)
    
    S[:,:,N] = Qf
    s[:,N] = Qf*(X[:,N] - xf)
    v1 = 0.0
    v2 = 0.0

    mu = 0.0
    k = N-1
    
    while k >= 1
        q = Q*(X[:,k] - xf)
        r = R*(U[:,k])
        F_aug = F([X[:,k];U[:,k];dt])
        fx = F_aug[1:size(X,1),1:size(X,1)]
        fu = F_aug[1:size(X,1),size(X,1)+1:size(X,1)+size(U,1)]
        
        Qx[:,:,k] = q + fx'*s[:,k+1]
        Qu[:,:,k] = r + fu'*s[:,k+1]
        Qxx[:,:,k] = Q + fx'*S[:,:,k+1]*fx
        Quu[:,:,k] = R + fu'*(S[:,:,k+1] + mu*eye(n))*fu
        Qux[:,:,k] = fu'*(S[:,:,k+1] + mu*eye(n))*fx

        # regularization        
        if any(x->x < 0.0, (eigvals(Quu[:,:,k])))
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end
        
        K[:,:,k] = Quu[:,:,k]\Qux[:,:,k]
        l[:,k] = Quu[:,:,k]\Qu[:,:,k]
        s[:,k] = (Qx[:,:,k]' - Qu[:,:,k]'*K[:,:,k] + l[:,k]'*Quu[:,:,k]*K[:,:,k] - l[:,k]'*Qux[:,:,k])'
        S[:,:,k] = Qxx[:,:,k] + K[:,:,k]'*Quu[:,:,k]*K[:,:,k] - K[:,:,k]'*Qux[:,:,k] - Qux[:,:,k]'*K[:,:,k]

        # terms for line search
        v1 += l[:,k]'*Qu[:,:,k]
        v2 += l[:,k]'*Quu[:,:,k]*l[:,k]
        
        k = k - 1;
    end
    return K, l, v1, v2
end

function forwardpass(X,U,f,J,K,l,v1,v2,c1=0.5,c2=0.85)
    N = size(X,2)
    m = size(U,1)
    X_prev = copy(X)
    J_prev = copy(J)
    du = zeros(m,N-1)
    J = Inf
    dV = 0.0
    dJ = 0.0
    z = 0.0
    
    alpha = 1.0
    iter = 0
    max_iter = 20
    while J > J_prev || z < c1 || z > c2 
        if iter > max_iter
            println("Problem")
            println("u: \n $(U+du)")
            break
        end
        for k = 1:N-1
            du[:,k] = -K[:,:,k]*(X[:,k] - X_prev[:,k]) - alpha*l[:,k]
            if k == N-1
                X[:,k+1] = f(X[:,k],U[:,k],U[:,k],du[:,k],dt)
            else
                X[:,k+1] = f(X[:,k],U[:,k],U[:,k+1],du[:,k],dt)
            end
        end

        J = cost(X,U + du,Q,R,Qf,xf)
        
        dV = alpha*v1 + (alpha^2)*v2/2.0
        dJ = J_prev - J
        z = dJ/dV[1]

        alpha = alpha/2.0;
        iter += 1
    end

    println("New cost: $J")
    println("- Expected improvement: $(dV[1])")
    println("- Actual improvement: $(dJ)")
    println("- (z = $z)\n")
    
    return X, copy(U + du), J
end

function solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,iterations=100,eps=1e-5;control_init="random")
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    
    if control_init == "random"
        U = 10.0*rand(m,N-1)
        println("initial control: random")
    else
        U = zeros(m,N-1)
    end
        
    X = rollout(x0,U,f,dt,tf)
    J_prev = cost(X,U,Q,R,Qf,xf)
    println("Initial Cost: $J_prev\n")
    
    for i = 1:iterations
        println("*** Iteration: $i ***")
        K, l, v1, v2 = backwardpass(X,U,F,Q,R,Qf,xf)
        X, U, J = forwardpass(X,U,f,J_prev,K,l,v1,v2)

        if abs(J-J_prev) < eps
          println("-----SOLVED-----")
          println("eps criteria met at iteration: $i")
          break
        end
        J_prev = copy(J)
    end
    
    return X, U
end
# Out:
# solve (generic function with 3 methods)

# %%
X, U = solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,control_init="random");
# Out:
# initial control: random
# Initial Cost: 42687.34415401852
#
# *** Iteration: 1 ***
# New cost: 11836.625461285757
# - Expected improvement: 53043.444150663425
# - Actual improvement: 30850.718692732764
# - (z = 0.5816122837933575)
#
# *** Iteration: 2 ***
# New cost: 2654.1267630516627
# - Expected improvement: 14441.643547618007
# - Actual improvement: 9182.498698234094
# - (z = 0.6358347419361869)
#
# *** Iteration: 3 ***
# New cost: 1956.5009673238362
# - Expected improvement: 1286.3526439729349
# - Actual improvement: 697.6257957278265
# - (z = 0.5423285745137433)
#
# *** Iteration: 4 ***
# New cost: 605.3986251673062
# - Expected improvement: 2165.302711122915
# - Actual improvement: 1351.10234215653
# - (z = 0.6239785020431879)
#
# *** Iteration: 5 ***
# New cost: 510.284081587772
# - Expected improvement: 171.073494143755
# - Actual improvement: 95.11454357953426
# - (z = 0.5559864434615945)
#
# *** Iteration: 6 ***
# New cost: 391.6510254093878
# - Expected improvement: 213.92477229057573
# - Actual improvement: 118.63305617838421
# - (z = 0.5545550190757897)
#
# *** Iteration: 7 ***
# New cost: 267.7958865640808
# - Expected improvement: 239.2015340785655
# - Actual improvement: 123.85513884530701
# - (z = 0.5177857212430207)
#
# *** Iteration: 8 ***
# New cost: 226.52792419267297
# - Expected improvement: 64.13612408035041
# - Actual improvement: 41.267962371407805
# - (z = 0.6434433474605803)
#
# *** Iteration: 9 ***
# New cost: 209.01057446653198
# - Expected improvement: 24.59093893405116
# - Actual improvement: 17.517349726140992
# - (z = 0.7123497713169731)
#
# *** Iteration: 10 ***
# New cost: 196.61447745123843
# - Expected improvement: 18.086389776576905
# - Actual improvement: 12.396097015293549
# - (z = 0.6853826091566008)
#
# *** Iteration: 11 ***
# New cost: 186.43636477211018
# - Expected improvement: 16.17387154318946
# - Actual improvement: 10.178112679128247
# - (z = 0.6292935276473168)
#
# *** Iteration: 12 ***
# New cost: 179.21348323588427
# - Expected improvement: 12.260259897041994
# - Actual improvement: 7.222881536225913
# - (z = 0.5891295614351993)
#
# *** Iteration: 13 ***
# New cost: 174.6150794418299
# - Expected improvement: 7.983880555631599
# - Actual improvement: 4.598403794054377
# - (z = 0.5759609956602866)
#
# *** Iteration: 14 ***
# New cost: 171.78600406419494
# - Expected improvement: 4.999007241114686
# - Actual improvement: 2.8290753776349504
# - (z = 0.5659274414261738)
#
# *** Iteration: 15 ***
# New cost: 170.0545413770818
# - Expected improvement: 3.147325168292432
# - Actual improvement: 1.7314626871131509
# - (z = 0.5501378454811992)
#
# *** Iteration: 16 ***
# New cost: 169.01254622429266
# - Expected improvement: 1.9969272732872547
# - Actual improvement: 1.0419951527891271
# - (z = 0.5217992496410949)
#
# *** Iteration: 17 ***
# Problem
# u:
#  [4.95307 5.52017 5.9092 6.09757 6.07814 5.85864 5.46793 4.95463 4.36498 3.74694 3.15037 2.59403 2.0895 1.64922 1.26102 0.916249 0.604228 0.324766 0.0664028 -0.19108 -0.446669 -0.712215 -0.986259 -1.27672 -1.57779 -1.88464 -2.18944 -2.48303 -2.74168 -2.95694 -3.12415 -3.25627 -3.35574 -3.42947 -3.49037 -3.54113 -3.59181 -3.62341 -3.59816 -3.48175 -3.25902 -2.91753 -2.44493 -1.86956 -1.24448 -0.585706 0.145802 0.955175 1.81979]
# New cost: 169.29744749701493
# - Expected improvement: 1.9469684563684077e-6
# - Actual improvement: -0.28490127272226573
# - (z = -146330.70802476132)
#
# *** Iteration: 18 ***
# New cost: 168.3876648067592
# - Expected improvement: 1.3109094835217645
# - Actual improvement: 0.9097826902557244
# - (z = 0.6940087791657353)
#
# *** Iteration: 19 ***
# Problem
# u:
#  [5.0616 5.6208 5.99712 6.16938 6.1307 5.89082 5.48034 4.94798 4.3438 3.71691 3.11251 2.5515 2.04516 1.6011 1.20983 0.862584 0.548794 0.26367 -0.00398522 -0.269722 -0.536705 -0.814335 -1.10343 -1.40779 -1.72106 -2.0343 -2.33444 -2.60733 -2.83359 -3.00676 -3.12787 -3.21179 -3.27003 -3.31565 -3.36127 -3.40888 -3.45835 -3.48875 -3.46513 -3.35346 -3.13401 -2.79669 -2.34057 -1.79348 -1.19742 -0.568548 0.115113 0.863059 1.6749]
# New cost: 168.6354447603486
# - Expected improvement: 1.242806602621351e-6
# - Actual improvement: -0.24777995358940075
# - (z = -199371.2883941706)
#
# *** Iteration: 20 ***
# New cost: 167.61590760680468
# - Expected improvement: 2.0064583919346237
# - Actual improvement: 1.0195371535439222
# - (z = 0.5081277327464968)
#
# *** Iteration: 21 ***
# Problem
# u:
#  [5.25988 5.80279 6.15461 6.29612 6.22154 5.94395 5.49719 4.93129 4.30134 3.65794 3.04055 2.47203 1.9626 1.51363 1.11828 0.767192 0.449541 0.155007 -0.127332 -0.407796 -0.693991 -0.991982 -1.30381 -1.62687 -1.95172 -2.26266 -2.54017 -2.76629 -2.93004 -3.03183 -3.08315 -3.10379 -3.11561 -3.13662 -3.17609 -3.2316 -3.28891 -3.32237 -3.29875 -3.18514 -2.95966 -2.61888 -2.17818 -1.66667 -1.11344 -0.53291 0.0795003 0.738989 1.47028]
# New cost: 168.02403217394465
# - Expected improvement: 4.632651622091292e-7
# - Actual improvement: -0.40812456713996426
# - (z = -880974.0089105315)
#
# *** Iteration: 22 ***
# New cost: 167.6120355263132
# - Expected improvement: 0.7705863344589893
# - Actual improvement: 0.4119966476314403
# - (z = 0.5346534569947876)
#
# *** Iteration: 23 ***
# Problem
# u:
#  [5.41573 5.9433 6.27375 6.3888 6.28419 5.97556 5.4997 4.90901 4.26073 3.6058 2.98167 2.41037 1.90047 1.45089 1.05448 0.700987 0.378881 0.0765511 -0.216969 -0.511388 -0.814392 -1.13046 -1.45926 -1.79387 -2.11989 -2.41685 -2.66299 -2.84255 -2.95187 -3.00126 -3.01165 -3.00806 -3.01257 -3.03923 -3.09122 -3.15986 -3.2249 -3.25685 -3.22224 -3.09224 -2.85209 -2.50642 -2.07652 -1.5902 -1.07011 -0.526509 0.044139 0.657351 1.33922]
# New cost: 167.90790751498378
# - Expected improvement: 1.8472188109713088e-7
# - Actual improvement: -0.2958719886705694
# - (z = -1.6017159792509547e6)
#
# *** Iteration: 24 ***
# New cost: 167.73805264758974
# - Expected improvement: 0.3023255683980392
# - Actual improvement: 0.16985486739403655
# - (z = 0.5618276624569415)
#
# *** Iteration: 25 ***
# Problem
# u:
#  [5.52749 6.04315 6.35737 6.45254 6.32569 5.99439 5.4977 4.88995 4.22944 3.56704 2.93925 2.36681 1.857 1.40759 1.01067 0.655372 0.329743 0.021873 -0.279315 -0.583383 -0.89742 -1.22459 -1.56232 -1.90056 -2.22153 -2.50246 -2.722 -2.86818 -2.94367 -2.9653 -2.95823 -2.94825 -2.95539 -2.99017 -3.05187 -3.12809 -3.19545 -3.22265 -3.17685 -3.03292 -2.78183 -2.4334 -2.01085 -1.5403 -1.04096 -0.520289 0.0263848 0.614381 1.26808]
# New cost: 167.94180142096155
# - Expected improvement: 7.477224677611761e-8
# - Actual improvement: -0.20374877337181374
# - (z = -2.724925118030444e6)
#
# *** Iteration: 26 ***
# New cost: 167.86965880741195
# - Expected improvement: 0.12133552878459344
# - Actual improvement: 0.07214261354960172
# - (z = 0.594571221407674)
#
# *** Iteration: 27 ***
# Problem
# u:
#  [5.60391 6.11111 6.41388 6.49512 6.35277 6.00581 5.4949 4.87569 4.20712 3.53994 2.90996 2.33694 1.82729 1.37806 0.980778 0.624173 0.29603 -0.0157222 -0.322215 -0.632853 -0.954206 -1.28841 -1.6312 -1.97037 -2.28605 -2.55447 -2.75534 -2.87995 -2.93534 -2.94203 -2.92694 -2.91553 -2.92614 -2.967 -3.03502 -3.11555 -3.18333 -3.20617 -3.15201 -2.99838 -2.74 -2.38964 -1.97137 -1.5101 -1.02313 -0.516361 0.0156776 0.588258 1.22489]
# New cost: 168.0066008176884
# - Expected improvement: 3.061169273099903e-8
# - Actual improvement: -0.13694201027644226
# - (z = -4.473519693269608e6)
#
# *** Iteration: 28 ***
# New cost: 167.97479872842447
# - Expected improvement: 0.049348483427362116
# - Actual improvement: 0.0318020892639197
# - (z = 0.644439039565023)
#
# *** Iteration: 29 ***
# Problem
# u:
# New cost: 168.13936249700126
# - Expected improvement: 2.206758092554254e-9
# - Actual improvement: 0.0016086543082280969
# - (z = 728967.218317133)
#
# *** Iteration: 35 ***
# New cost: 168.13752556439044
# - Expected improvement: 0.003485762690833394
# - Actual improvement: 0.0018369326108143014
# - (z = 0.52698154571593)
#
# *** Iteration: 36 ***
# Problem
# u:
#  [5.72347 6.217 6.5014 6.56039 6.39347 6.02185 5.48876 4.8519 4.17113 3.49687 2.86377 2.29013 1.78092 1.3321 0.934334 0.575776 0.243809 -0.0738533 -0.38833 -0.708637 -1.04036 -1.38381 -1.73199 -2.06943 -2.3736 -2.62032 -2.79224 -2.88635 -2.91592 -2.90571 -2.8838 -2.87418 -2.89233 -2.94312 -3.02002 -3.1052 -3.17097 -3.18438 -3.11526 -2.94565 -2.67571 -2.32209 -1.90961 -1.46143 -0.992236 -0.505806 0.00443724 0.553839 1.16516]
# New cost: 168.16224344909367
# - Expected improvement: 8.961866806994278e-10
# - Actual improvement: -0.02471788470322167
# - (z = -2.7581178381194673e7)
#
# *** Iteration: 37 ***
# Problem
# u:
#  [5.72347 6.21699 6.50139 6.56035 6.39339 6.02174 5.48861 4.85175 4.171 3.49678 2.86374 2.29015 1.78099 1.33218 0.934421 0.575856 0.243877 -0.0737981 -0.388286 -0.708602 -1.04033 -1.38378 -1.73196 -2.0694 -2.37357 -2.62029 -2.79221 -2.88632 -2.9159 -2.9057 -2.8838 -2.87421 -2.89237 -2.94316 -3.02008 -3.10526 -3.17104 -3.18444 -3.1153 -2.94567 -2.67571 -2.32208 -1.90962 -1.46149 -0.992335 -0.505941 0.00427047 0.553622 1.1648]
# New cost: 168.16118088711613
# - Expected improvement: 9.159979416055962e-10
# - Actual improvement: 0.00106256197753396
# - (z = 1.1600047655909148e6)
#
# *** Iteration: 38 ***
# New cost: 168.16043347076035
# - Expected improvement: 0.0014467342673814625
# - Actual improvement: 0.0007474163557787961
# - (z = 0.5166231094612787)
#
# *** Iteration: 39 ***
# Problem
# u:
#  [5.73249 6.22498 6.50799 6.56529 6.39648 6.02299 5.48821 4.85003 4.16835 3.49358 2.86027 2.2866 1.77745 1.32866 0.930863 0.572152 0.239887 -0.0782326 -0.393318 -0.714349 -1.04683 -1.39091 -1.7394 -2.07659 -2.37976 -2.62477 -2.79454 -2.8865 -2.91436 -2.90314 -2.88093 -2.87161 -2.89041 -2.94196 -3.01949 -3.10492 -3.17042 -3.18298 -3.11262 -2.94173 -2.67087 -2.31696 -1.90488 -1.45765 -0.989772 -0.50486 0.00374448 0.55139 1.16077]
# New cost: 168.17645376947104
# - Expected improvement: 3.72151677185791e-10
# - Actual improvement: -0.016020298710685665
# - (z = -4.30477670605466e7)
#
# *** Iteration: 40 ***
# Problem
# New cost: 168.18863024487098
# - Expected improvement: 1.0621356865526952e-10
# - Actual improvement: -0.0033370032187747256
# - (z = -3.1417861776261564e7)
#
# *** Iteration: 46 ***
# Problem
# u:
#  [5.7402 6.2318 6.51361 6.56945 6.39902 6.0239 5.48767 4.84836 4.16592 3.49074 2.85729 2.28362 1.77453 1.32578 0.927948 0.569095 0.236561 -0.0819617 -0.397578 -0.719236 -1.05237 -1.397 -1.74576 -2.08271 -2.38503 -2.62857 -2.7965 -2.88664 -2.91307 -2.90101 -2.87857 -2.86952 -2.88888 -2.94109 -3.01915 -3.1048 -3.17005 -3.18188 -3.11044 -2.93842 -2.66675 -2.31259 -1.90085 -1.45446 -0.987722 -0.50412 0.00307412 0.549197 1.15682]
# New cost: 168.18848497803043
# - Expected improvement: 1.0727335771502654e-10
# - Actual improvement: 0.00014526684054771977
# - (z = 1.3541744533961876e6)
#
# *** Iteration: 47 ***
# New cost: 168.18844050481903
# - Expected improvement: 7.041214100071053e-5
# - Actual improvement: 4.4473211403328605e-5
# - (z = 0.6316128265845492)
#
# *** Iteration: 48 ***
# Problem
# u:
#  [5.74174 6.23317 6.51474 6.57029 6.39955 6.02411 5.4876 4.84805 4.16546 3.49019 2.8567 2.28302 1.77393 1.32519 0.927346 0.568465 0.23588 -0.0827209 -0.398441 -0.720223 -1.05348 -1.39822 -1.74703 -2.08394 -2.38608 -2.62933 -2.79689 -2.88667 -2.91281 -2.90058 -2.8781 -2.8691 -2.88857 -2.94091 -3.01908 -3.10477 -3.16996 -3.18165 -3.10998 -2.93775 -2.66592 -2.31171 -1.90004 -1.4538 -0.98728 -0.503933 0.00298512 0.548813 1.15612]
# New cost: 168.19118503725494
# - Expected improvement: 7.185253835816354e-11
# - Actual improvement: -0.002744532435912106
# - (z = -3.81967359626382e7)
#
# *** Iteration: 49 ***
# Problem
# u:
#  [5.74174 6.23317 6.51474 6.57028 6.39954 6.0241 5.48758 4.84804 4.16545 3.49018 2.85669 2.28303 1.77394 1.3252 0.927356 0.568474 0.235887 -0.082715 -0.398436 -0.720219 -1.05348 -1.39822 -1.74703 -2.08393 -2.38608 -2.62933 -2.79689 -2.88666 -2.9128 -2.90058 -2.8781 -2.8691 -2.88858 -2.94091 -3.01909 -3.10478 -3.16997 -3.18165 -3.10999 -2.93775 -2.66592 -2.3117 -1.90004 -1.45381 -0.987292 -0.503949 0.0029655 0.548788 1.15607]
# New cost: 168.19106533560935
# - Expected improvement: 7.257620452979224e-11
# - Actual improvement: 0.00011970164558761098
# - (z = 1.6493235815118155e6)
#
# *** Iteration: 50 ***
# New cost: 168.19103625813966
# - Expected improvement: 4.7636802770413365e-5
# - Actual improvement: 2.9077469690719226e-5
# New cost: 168.19495151695452
# - Expected improvement: 3.322969031948977e-11
# - Actual improvement: 8.11651871686081e-5
# - (z = 2.442550213024506e6)
#
# *** Iteration: 56 ***
# New cost: 168.19493943131172
# - Expected improvement: 2.1811088894587253e-5
# - Actual improvement: 1.2085642794090745e-5
# - (z = 0.5541054301552994)
#
# *** Iteration: 57 ***
# Problem
# u:
#  [5.74491 6.23598 6.51706 6.57201 6.40061 6.02451 5.48741 4.8474 4.16449 3.48904 2.85548 2.2818 1.77272 1.32399 0.92613 0.567191 0.234495 -0.0842693 -0.400206 -0.722244 -1.05577 -1.40073 -1.74964 -2.08645 -2.38824 -2.63088 -2.79768 -2.88671 -2.91227 -2.89971 -2.87714 -2.86824 -2.88796 -2.94056 -3.01895 -3.10472 -3.16981 -3.18118 -3.10907 -2.93637 -2.66421 -2.30989 -1.89836 -1.45246 -0.9864 -0.503586 0.0027557 0.547964 1.15457]
# New cost: 168.19646652355672
# - Expected improvement: 2.2264789761760767e-11
# - Actual improvement: -0.0015270922449985846
# - (z = -6.858776846037541e7)
#
# *** Iteration: 58 ***
# Problem
# u:
#  [5.74491 6.23598 6.51706 6.57201 6.4006 6.0245 5.4874 4.84739 4.16448 3.48903 2.85547 2.2818 1.77273 1.324 0.926135 0.567195 0.234499 -0.0842661 -0.400203 -0.722242 -1.05577 -1.40073 -1.74964 -2.08645 -2.38823 -2.63087 -2.79768 -2.88671 -2.91227 -2.89971 -2.87714 -2.86825 -2.88796 -2.94056 -3.01895 -3.10472 -3.16981 -3.18118 -3.10907 -2.93637 -2.66421 -2.30989 -1.89836 -1.45246 -0.986407 -0.503595 0.00274478 0.54795 1.15454]
# New cost: 168.19639971129777
# - Expected improvement: 2.2487777558126358e-11
# - Actual improvement: 6.68122589502218e-5
# - (z = 2.971047662559167e6)
#
# *** Iteration: 59 ***
# New cost: 168.19639208608947
# - Expected improvement: 1.476040539045498e-5
# - Actual improvement: 7.625208297667996e-6
# - (z = 0.5165988396632346)
#
# -----SOLVED-----
# eps criteria met at iteration: 59

# %%
P = plot(linspace(0,tf,size(X,2)),X[1,:])
P = plot!(linspace(0,tf,size(X,2)),X[2,:])

# %%
W = plot(linspace(0,tf,size(X,2)),[U[1,:]; U[1,end]],title="Pendulum",ylabel="Control")

# %%
plt = plot()
@gif for i=1:size(X,2)
    x = cos(X[1,i] - pi/2)
    y = sin(X[1,i] - pi/2)
    plt = plot([0,x],[0,y],xlims=(-1.5,1.5),ylims=(-1.5,1.5),color="black",size=(200,200),label="",title="Pendulum")
end
# Out:
# INFO: Saved animation to C:\Users\taylor howell\Google Drive\Stanford\Research-Manchester\iLQR demos\tmp.gif
# Plots.AnimatedGif("C:\\Users\\taylor howell\\Google Drive\\Stanford\\Research-Manchester\\iLQR demos\\tmp.gif")
