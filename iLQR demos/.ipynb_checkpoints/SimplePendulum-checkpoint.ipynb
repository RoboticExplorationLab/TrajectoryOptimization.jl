# %%
using ForwardDiff
using Plots

# %%
## Simple Pendulum
n = 2 # number of states 
m = 1 # number of controls

#initial and goal conditions
x0 = [0.; 0.]
xf = [pi; 0.] # (ie, swing up)

#costs
Q = 0.3*eye(n)
Qf = 30.0*eye(n)
R = 0.3*eye(m)

#simulation
dt = 0.1
tf = 5.
# Out:
# 5.0

# %%
# Dynamics 
function fc(x,u)
    # continuous dynamics (as defined in https://github.com/HarvardAgileRoboticsLab/unscented-dynamic-programming/blob/master/pendulum_dynamics.m)
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (u - m*g*lc*sin(x[1]) - b*x[2])];
end

function f(x,u,dt)
    # RK4
    k1 = dt*fc(x,u)
    k2 = dt*fc(x + k1/2,u)
    k3 = dt*fc(x + k2/2,u)
    k4 = dt*fc(x + k3, u)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

function fc_aug(S)
    # augmented continuous dynamics
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [S[2]; (S[3] - m*g*lc*sin(S[1]) - b*S[2]); 0.0; 0.0];
end

function f2_aug(S)
    # RK4
    k1 = S[4]*fc_aug(S)
    k2 = S[4]*fc_aug(S + k1/2)
    k3 = S[4]*fc_aug(S + k2/2)
    k4 = S[4]*fc_aug(S + k3)
    return S + (k1 + 2*k2 + 2*k3 + k4)/6
end

F = S-> ForwardDiff.jacobian(f2_aug,S)
# Out:
# (::#1) (generic function with 1 method)

# %%
#iLQR
function rollout(x0,U,f,dt,tf)
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    X[:,1] = x0
    for k = 1:N-1
      X[:,k+1] = f(X[:,k],U[:,k],dt)
    end
    return X
end

function cost(X,U,Q,R,Qf,xf)
    N = size(X,2)
    J = 0.0
    for k = 1:N-1
      J += 0.5*(X[:,k] - xf)'*Q*(X[:,k] - xf) + 0.5*U[:,k]'*R*U[:,k]
    end
    J += 0.5*(X[:,N] - xf)'*Qf*(X[:,N] - xf)
    return J
end

function backwardpass(X,U,F,Q,R,Qf,xf)
    n, N = size(X)
    m = size(U,1)
    
    S = zeros(n,n,N)
    s = zeros(n,N)
    
    Qx = zeros(n,1,N)
    Qu = zeros(m,1,N)
    Qxx = zeros(n,n,N)
    Quu = zeros(m,m,N)
    Qux = zeros(m,n,N)
    
    K = zeros(m,n,N-1)
    l = zeros(m,N-1)
    
    S[:,:,N] = Qf
    s[:,N] = Qf*(X[:,N] - xf)
    v1 = 0.0
    v2 = 0.0

    mu = 0.0
    k = N-1
    
    while k >= 1
        q = Q*(X[:,k] - xf)
        r = R*(U[:,k])
        F_aug = F([X[:,k];U[:,k];dt])
        fx = F_aug[1:size(X,1),1:size(X,1)]
        fu = F_aug[1:size(X,1),size(X,1)+1:size(X,1)+size(U,1)]
        
        Qx[:,:,k] = q + fx'*s[:,k+1]
        Qu[:,:,k] = r + fu'*s[:,k+1]
        Qxx[:,:,k] = Q + fx'*S[:,:,k+1]*fx
        Quu[:,:,k] = R + fu'*(S[:,:,k+1] + mu*eye(n))*fu
        Qux[:,:,k] = fu'*(S[:,:,k+1] + mu*eye(n))*fx

        # regularization        
        if any(x->x < 0.0, (eigvals(Quu[:,:,k])))
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end
        
        K[:,:,k] = Quu[:,:,k]\Qux[:,:,k]
        l[:,k] = Quu[:,:,k]\Qu[:,:,k]
        s[:,k] = (Qx[:,:,k]' - Qu[:,:,k]'*K[:,:,k] + l[:,k]'*Quu[:,:,k]*K[:,:,k] - l[:,k]'*Qux[:,:,k])'
        S[:,:,k] = Qxx[:,:,k] + K[:,:,k]'*Quu[:,:,k]*K[:,:,k] - K[:,:,k]'*Qux[:,:,k] - Qux[:,:,k]'*K[:,:,k]

        # terms for line search
        v1 += l[:,k]'*Qu[:,:,k]
        v2 += l[:,k]'*Quu[:,:,k]*l[:,k]
        
        k = k - 1;
    end
    return K, l, v1, v2
end

function forwardpass(X,U,f,J,K,l,v1,v2,c1=0.0,c2=1.0)
    N = size(X,2)
    m = size(U,1)
    X_prev = copy(X)
    J_prev = copy(J)
    U_ = zeros(m,N-1)
    J = Inf
    dV = 0.0
    dJ = 0.0
    z = 0.0
    
    alpha = 1.0

    while J > J_prev || z < c1 || z > c2 
        for k = 1:N-1
          U_[:,k] = U[:,k] - K[:,:,k]*(X[:,k] - X_prev[:,k]) - alpha*l[:,k]
          X[:,k+1] = f(X[:,k],U_[:,k],dt);
        end

        J = cost(X,U_,Q,R,Qf,xf)
        
        dV = alpha*v1 + (alpha^2)*v2/2.0
        dJ = J_prev - J
        z = dJ/dV[1]

        alpha = alpha/2.0;
    end

    println("New cost: $J")
    println("- Expected improvement: $(dV[1])")
    println("- Actual improvement: $(dJ)")
    println("- (z = $z)\n")
    
    return X, U_, J
end

function solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,iterations=100,eps=1e-5;control_init="random")
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    
    if control_init == "random"
        U = rand(m,N-1)
    else
        U = zeros(m,N-1)
    end
        
    X = rollout(x0,U,f,dt,tf)
    J_prev = cost(X,U,Q,R,Qf,xf)
    println("Initial Cost: $J_prev\n")
    
    for i = 1:iterations
        println("*** Iteration: $i ***")
        K, l, v1, v2 = backwardpass(X,U,F,Q,R,Qf,xf)
        X, U, J = forwardpass(X,U,f,J_prev,K,l,v1,v2)

        if abs(J-J_prev) < eps
          println("-----SOLVED-----")
          println("eps criteria met at iteration: $i")
          break
        end
        J_prev = copy(J)
    end
    
    return X, U
end
# Out:
# solve (generic function with 3 methods)

# %%
X, U = solve(x0,m,f,F,Q,R,Qf,xf,dt,tf;control_init="random");
# Out:
# Initial Cost: 208.4236381098563
#
# *** Iteration: 1 ***
# New cost: 132.9945734527581
# - Expected improvement: 260.66651224542403
# - Actual improvement: 75.42906465709822
# - (z = 0.2893699846878677)
#
# *** Iteration: 2 ***
# New cost: 103.29224659223517
# - Expected improvement: 78.62134960624864
# - Actual improvement: 29.702326860522916
# - (z = 0.37778958271866453)
#
# *** Iteration: 3 ***
# New cost: 98.03828024876456
# - Expected improvement: 9.612812254725144
# - Actual improvement: 5.2539663434706085
# - (z = 0.5465587181199799)
#
# *** Iteration: 4 ***
# New cost: 95.07674339045025
# - Expected improvement: 4.843050613260391
# - Actual improvement: 2.961536858314318
# - (z = 0.6115023556032138)
#
# *** Iteration: 5 ***
# New cost: 93.00285037934175
# - Expected improvement: 3.2487685833712887
# - Actual improvement: 2.0738930111084954
# - (z = 0.6383628005157542)
#
# *** Iteration: 6 ***
# New cost: 91.40419897197916
# - Expected improvement: 2.458772953466629
# - Actual improvement: 1.5986514073625955
# - (z = 0.6501826063722775)
#
# *** Iteration: 7 ***
# New cost: 90.10865996804003
# - Expected improvement: 1.9716703552136279
# - Actual improvement: 1.2955390039391261
# - (z = 0.6570768792629923)
#
# *** Iteration: 8 ***
# New cost: 89.02211716390893
# - Expected improvement: 1.6421198051878059
# - Actual improvement: 1.0865428041310992
# - (z = 0.6616708480699638)
#
# *** Iteration: 9 ***
# New cost: 88.08587387866515
# - Expected improvement: 1.4071919004672722
# - Actual improvement: 0.9362432852437763
# - (z = 0.6653273693039928)
#
# *** Iteration: 10 ***
# New cost: 87.2594118527911
# - Expected improvement: 1.2359816972067854
# - Actual improvement: 0.8264620258740507
# - (z = 0.6686684986855269)
#
# *** Iteration: 11 ***
# New cost: 86.51266068848754
# - Expected improvement: 1.1111993799983313
# - Actual improvement: 0.7467511643035607
# - (z = 0.6720226610499748)
#
# *** Iteration: 12 ***
# New cost: 85.82192168274477
# - Expected improvement: 1.0224624431712017
# - Actual improvement: 0.6907390057427705
# - (z = 0.6755641836588346)
#
# *** Iteration: 13 ***
# New cost: 85.16743065880075
# - Expected improvement: 0.9633603226097529
# - Actual improvement: 0.6544910239440185
# - (z = 0.6793834130214078)
#
# *** Iteration: 14 ***
# New cost: 84.53170502251885
# - Expected improvement: 0.9300812747981213
# - Actual improvement: 0.6357256362819044
# - (z = 0.6835162189668765)
#
# *** Iteration: 15 ***
# New cost: 83.89829034785006
# - Expected improvement: 0.9207240590816139
# - Actual improvement: 0.633414674668785
# - (z = 0.6879527784910837)
#
# *** Iteration: 16 ***
# New cost: 83.25073159627483
# - Expected improvement: 0.9349254865167611
# - Actual improvement: 0.6475587515752323
# - (z = 0.6926314031590186)
#
# *** Iteration: 17 ***
# New cost: 82.5717279659368
# - Expected improvement: 0.9735952493427666
# - Actual improvement: 0.6790036303380305
# - (z = 0.6974187998517838)
#
# *** Iteration: 18 ***
# New cost: 81.84257795299699
# - Expected improvement: 1.038561488291323
# - Actual improvement: 0.7291500129398116
# - (z = 0.7020768834201953)
#
# *** Iteration: 19 ***
# New cost: 81.0432498062129
# - Expected improvement: 1.131840497459395
# - Actual improvement: 0.7993281467840916
# - (z = 0.7062197797112907)
#
# *** Iteration: 20 ***
# New cost: 80.15375619029375
# - Expected improvement: 1.2540849631932252
# - Actual improvement: 0.8894936159191502
# - (z = 0.7092769963960568)
#
# *** Iteration: 21 ***
# New cost: 79.15785364799925
# - Expected improvement: 1.401684332178815
# - Actual improvement: 0.9959025422945018
# - (z = 0.7105041552019381)
#
# *** Iteration: 22 ***
# New cost: 78.04989305957632
# - Expected improvement: 1.5624608671118092
# - Actual improvement: 1.1079605884229267
# - (z = 0.7091125363484968)
#
# *** Iteration: 23 ***
# New cost: 76.84384412217723
# - Expected improvement: 1.7117392232018789
# - Actual improvement: 1.206048937399089
# - (z = 0.7045751601947432)
#
# *** Iteration: 24 ***
# New cost: 75.57967042690392
# - Expected improvement: 1.8136566696945324
# - Actual improvement: 1.264173695273314
# - (z = 0.6970303235431181)
#
# *** Iteration: 25 ***
# New cost: 74.31955352943748
# - Expected improvement: 1.832947367543909
# - Actual improvement: 1.2601168974664319
# - (z = 0.6874812227450635)
#
# *** Iteration: 26 ***
# New cost: 73.13128477438467
# - Expected improvement: 1.7538998626659679
# - Actual improvement: 1.1882687550528175
# - (z = 0.6775009111675405)
#
# *** Iteration: 27 ***
# New cost: 72.06739671517383
# - Expected improvement: 1.5912338135845816
# - Actual improvement: 1.0638880592108393
# - (z = 0.6685931697329964)
#
# *** Iteration: 28 ***
# New cost: 71.15313495707414
# - Expected improvement: 1.3816627375245987
# - Actual improvement: 0.9142617580996841
# - (z = 0.6617112362295339)
#
# *** Iteration: 29 ***
# New cost: 70.38788934962164
# - Expected improvement: 1.1644121986660059
# - Actual improvement: 0.7652456074524991
# - (z = 0.6571947703134621)
#
# *** Iteration: 30 ***
# New cost: 69.75450722908369
# - Expected improvement: 0.967038543520513
# - Actual improvement: 0.6333821205379593
# - (z = 0.6549709158769677)
#
# *** Iteration: 31 ***
# New cost: 69.2290170784533
# - Expected improvement: 0.8025446021028529
# - Actual improvement: 0.5254901506303895
# - (z = 0.6547799950974481)
#
# *** Iteration: 32 ***
# New cost: 68.78707403508027
# - Expected improvement: 0.6733632893147592
# - Actual improvement: 0.4419430433730298
# - (z = 0.6563218553580019)
#
# *** Iteration: 33 ***
# New cost: 68.40696090743172
# - Expected improvement: 0.5765172415931505
# - Actual improvement: 0.3801131276485421
# - (z = 0.6593265564758057)
#
# *** Iteration: 34 ***
# New cost: 68.07030740581273
# - Expected improvement: 0.5073289793411023
# - Actual improvement: 0.3366535016189971
# - (z = 0.6635802710427238)
#
# *** Iteration: 35 ***
# New cost: 67.76163587848045
# - Expected improvement: 0.4614413088355795
# - Actual improvement: 0.30867152733227954
# - (z = 0.6689291171421006)
#
# *** Iteration: 36 ***
# New cost: 67.46740056049762
# - Expected improvement: 0.43572851924314215
# - Actual improvement: 0.29423531798282454
# - (z = 0.6752721132275425)
#
# *** Iteration: 37 ***
# New cost: 67.17480201758677
# - Expected improvement: 0.42868651685643744
# - Actual improvement: 0.2925985429108522
# - (z = 0.6825466428393416)
#
# *** Iteration: 38 ***
# New cost: 66.87040832481904
# - Expected improvement: 0.44070067708285043
# - Actual improvement: 0.3043936927677322
# - (z = 0.6907039371543945)
#
# *** Iteration: 39 ***
# New cost: 66.53846380191224
# - Expected improvement: 0.4744334423232265
# - Actual improvement: 0.3319445229067952
# - (z = 0.6996651021928697)
#
# *** Iteration: 40 ***
# New cost: 66.15869555442998
# - Expected improvement: 0.5354603780733742
# - Actual improvement: 0.3797682474822608
# - (z = 0.7092368792041996)
#
# *** Iteration: 41 ***
# New cost: 65.70353802657901
# - Expected improvement: 0.6330886622659473
# - Actual improvement: 0.45515752785097163
# - (z = 0.71894752659426)
#
# *** Iteration: 42 ***
# New cost: 65.13542935873183
# - Expected improvement: 0.7806473555802298
# - Actual improvement: 0.5681086678471843
# - (z = 0.7277404628174621)
#
# *** Iteration: 43 ***
# New cost: 64.40743921083225
# - Expected improvement: 0.992519212375622
# - Actual improvement: 0.7279901478995754
# - (z = 0.7334771345706357)
#
# *** Iteration: 44 ***
# New cost: 63.47694119651689
# - Expected improvement: 1.270452518550684
# - Actual improvement: 0.9304980143153614
# - (z = 0.7324146323680492)
#
# *** Iteration: 45 ***
# New cost: 62.34889121060448
# - Expected improvement: 1.5676885338327522
# - Actual improvement: 1.128049985912412
# - (z = 0.7195625671602681)
#
# *** Iteration: 46 ***
# New cost: 61.14260265635597
# - Expected improvement: 1.743965731480826
# - Actual improvement: 1.2062885542485091
# - (z = 0.6916928082206251)
#
# *** Iteration: 47 ***
# New cost: 60.089219701043255
# - Expected improvement: 1.6146618505339319
# - Actual improvement: 1.0533829553127134
# - (z = 0.6523861048456577)
#
# *** Iteration: 48 ***
# New cost: 59.371779395264696
# - Expected improvement: 1.172324456692138
# - Actual improvement: 0.7174403057785597
# - (z = 0.6119810106179209)
#
# *** Iteration: 49 ***
# New cost: 58.98690055775427
# - Expected improvement: 0.6641768153104901
# - Actual improvement: 0.38487883751042773
# - (z = 0.5794824941766511)
#
# *** Iteration: 50 ***
# New cost: 58.8155723267916
# - Expected improvement: 0.30745769293362374
# - Actual improvement: 0.17132823096266492
# - (z = 0.5572416462503429)
#
# *** Iteration: 51 ***
# New cost: 58.74833649393947
# - Expected improvement: 0.1237535866308433
# - Actual improvement: 0.06723583285213408
# - (z = 0.5433041149158645)
#
# *** Iteration: 52 ***
# New cost: 58.72393562744297
# - Expected improvement: 0.04561398876280985
# - Actual improvement: 0.024400866496499418
# - (z = 0.5349426164719454)
#
# *** Iteration: 53 ***
# New cost: 58.7154828212399
# - Expected improvement: 0.01594759600346842
# - Actual improvement: 0.008452806203067098
# - (z = 0.5300363892607205)
#
# *** Iteration: 54 ***
# New cost: 58.712633025017375
# - Expected improvement: 0.005405609540171814
# - Actual improvement: 0.0028497962225273454
# - (z = 0.5271923917828454)
#
# *** Iteration: 55 ***
# New cost: 58.711687167187726
# - Expected improvement: 0.0017997303772856095
# - Actual improvement: 0.000945857829648844
# - (z = 0.5255552951633824)
#
# *** Iteration: 56 ***
# New cost: 58.71137604305092
# - Expected improvement: 0.0005930503168945006
# - Actual improvement: 0.0003111241368074502
# - (z = 0.5246167617558106)
#
# *** Iteration: 57 ***
# New cost: 58.71127422918306
# - Expected improvement: 0.0001942716211681176
# - Actual improvement: 0.00010181386785745872
# - (z = 0.5240799826823479)
#
# *** Iteration: 58 ***
# New cost: 58.71124100889899
# - Expected improvement: 6.342491632048029e-5
# - Actual improvement: 3.3220284073820494e-5
# - (z = 0.5237734001249831)
#
# *** Iteration: 59 ***
# New cost: 58.71123018781183
# - Expected improvement: 2.0666767564472297e-5
# - Actual improvement: 1.082108715877439e-5
# - (z = 0.5235984352665116)
#
# *** Iteration: 60 ***
# New cost: 58.711226666352964
# - Expected improvement: 6.726777703587581e-6
# - Actual improvement: 3.521458864952365e-6
# - (z = 0.5234986229847125)
#
# -----SOLVED-----
# eps criteria met at iteration: 60

# %%
P = plot(linspace(0,tf,size(X,2)),X[1,:])
P = plot!(linspace(0,tf,size(X,2)),X[2,:])

# %%
W = plot(linspace(0,tf,size(X,2)),[U[1,:]; U[1,end]],title="Pendulum",ylabel="Control")

# %%
plt = plot()
@gif for i=1:size(X,2)
    x = cos(X[1,i] - pi/2)
    y = sin(X[1,i] - pi/2)
    plt = plot([0,x],[0,y],xlims=(-1.5,1.5),ylims=(-1.5,1.5),color="black",size=(200,200),label="",title="Pendulum")
end
