# %%
using ForwardDiff
using Plots

# %%
## Simple Pendulum
n = 2 # number of states 
m = 1 # number of controls

#initial and goal conditions
x0 = [0.; 0.]
xf = [pi; 0.] # (ie, swing up)

#costs
Q = 0.3*eye(n)
Qf = 30.0*eye(n)
R = 0.3*eye(m)

#simulation
dt = 0.1
tf = 5.
# Out:
# 5.0

# %%
# Dynamics 
function fc(x,u)
    # continuous dynamics (as defined in https://github.com/HarvardAgileRoboticsLab/unscented-dynamic-programming/blob/master/pendulum_dynamics.m)
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (u - m*g*lc*sin(x[1]) - b*x[2])];
end

function f(x,u1,u2,du,dt)
    # RK4
    k1 = dt*fc(x,u1+du)
    k2 = dt*fc(x + k1/2,(u1+u2)/2 + du)
    k3 = dt*fc(x + k2/2,(u1+u2)/2 + du)
    k4 = dt*fc(x + k3, u2 + du)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

function fc_aug(x)
    # augmented continuous dynamics
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (x[3] - m*g*lc*sin(x[1]) - b*x[2]); 0.0; 0.0]; # xd, xdd, u, dt
end

function f2_aug(x)
    # RK4
    #x[3] = x[4] + x[6] # u = u1 + du
    k1 = x[end]*fc_aug(x)
    #x[3] = (x[4]+x[5])/x[end] + x[6] # u = (u1+u2)/dt + du
    k2 = x[end]*fc_aug(x + k1/2)
    k3 = x[end]*fc_aug(x + k2/2)
    #x[3] = x[5] + x[6] # u = u2 + du
    k4 = x[end]*fc_aug(x + k3)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

F = x-> ForwardDiff.jacobian(f2_aug,x)
# Out:
# (::#33) (generic function with 1 method)

# %%
#iLQR
function rollout(x0,U,f,dt,tf)
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    X[:,1] = x0
    for k = 1:N-1
        if k == N-1
            X[:,k+1] = f(X[:,k],U[:,k],U[:,k],0.0,dt)
        else
            X[:,k+1] = f(X[:,k],U[:,k],U[:,k],0.0,dt)
        end
    end
    return X
end

function cost(X,U,Q,R,Qf,xf)
    N = size(X,2)
    J = 0.0
    for k = 1:N-1
      J += 0.5*(X[:,k] - xf)'*Q*(X[:,k] - xf) + 0.5*U[:,k]'*R*U[:,k]
    end
    J += 0.5*(X[:,N] - xf)'*Qf*(X[:,N] - xf)
    return J
end

function backwardpass(X,U,F,Q,R,Qf,xf)
    n, N = size(X)
    m = size(U,1)
    
    S = zeros(n,n,N)
    s = zeros(n,N)
    
    Qx = zeros(n,1,N)
    Qu = zeros(m,1,N)
    Qxx = zeros(n,n,N)
    Quu = zeros(m,m,N)
    Qux = zeros(m,n,N)
    
    K = zeros(m,n,N-1)
    l = zeros(m,N-1)
    
    S[:,:,N] = Qf
    s[:,N] = Qf*(X[:,N] - xf)
    v1 = 0.0
    v2 = 0.0

    mu = 0.0
    k = N-1
    
    while k >= 1
        q = Q*(X[:,k] - xf)
        r = R*(U[:,k])
        F_aug = F([X[:,k];U[:,k];dt])
        fx = F_aug[1:size(X,1),1:size(X,1)]
        fu = F_aug[1:size(X,1),size(X,1)+1:size(X,1)+size(U,1)]
        
        Qx[:,:,k] = q + fx'*s[:,k+1]
        Qu[:,:,k] = r + fu'*s[:,k+1]
        Qxx[:,:,k] = Q + fx'*S[:,:,k+1]*fx
        Quu[:,:,k] = R + fu'*(S[:,:,k+1] + mu*eye(n))*fu
        Qux[:,:,k] = fu'*(S[:,:,k+1] + mu*eye(n))*fx

        # regularization        
        if any(x->x < 0.0, (eigvals(Quu[:,:,k])))
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end
        
        K[:,:,k] = Quu[:,:,k]\Qux[:,:,k]
        l[:,k] = Quu[:,:,k]\Qu[:,:,k]
        s[:,k] = (Qx[:,:,k]' - Qu[:,:,k]'*K[:,:,k] + l[:,k]'*Quu[:,:,k]*K[:,:,k] - l[:,k]'*Qux[:,:,k])'
        S[:,:,k] = Qxx[:,:,k] + K[:,:,k]'*Quu[:,:,k]*K[:,:,k] - K[:,:,k]'*Qux[:,:,k] - Qux[:,:,k]'*K[:,:,k]

        # terms for line search
        v1 += l[:,k]'*Qu[:,:,k]
        v2 += l[:,k]'*Quu[:,:,k]*l[:,k]
        
        k = k - 1;
    end
    return K, l, v1, v2
end

function forwardpass(X,U,f,J,K,l,v1,v2,c1=0.5,c2=0.85)
    N = size(X,2)
    m = size(U,1)
    X_prev = copy(X)
    J_prev = copy(J)
    du = zeros(m,N-1)
    J = Inf
    dV = 0.0
    dJ = 0.0
    z = 0.0
    
    alpha = 1.0
    iter = 0
    max_iter = 20
    while J > J_prev || z < c1 || z > c2 
        if iter > max_iter
            println("Problem")
            println("u: \n $(U+du)")
            break
        end
        for k = 1:N-1
            du[:,k] = -K[:,:,k]*(X[:,k] - X_prev[:,k]) - alpha*l[:,k]
            if k == N-1
                X[:,k+1] = f(X[:,k],U[:,k],U[:,k],du[:,k],dt)
            else
                X[:,k+1] = f(X[:,k],U[:,k],U[:,k],du[:,k],dt)
            end
        end

        J = cost(X,U + du,Q,R,Qf,xf)
        
        dV = alpha*v1 + (alpha^2)*v2/2.0
        dJ = J_prev - J
        z = dJ/dV[1]

        alpha = alpha/2.0;
        iter += 1
    end

    println("New cost: $J")
    println("- Expected improvement: $(dV[1])")
    println("- Actual improvement: $(dJ)")
    println("- (z = $z)\n")
    
    return X, copy(U + du), J
end

function solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,iterations=100,eps=1e-5;control_init="random")
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    
    if control_init == "random"
        U = rand(m,N-1)
        println("initial control: random")
    else
        U = zeros(m,N-1)
    end
        
    X = rollout(x0,U,f,dt,tf)
    J_prev = cost(X,U,Q,R,Qf,xf)
    println("Initial Cost: $J_prev\n")
    
    for i = 1:iterations
        println("*** Iteration: $i ***")
        K, l, v1, v2 = backwardpass(X,U,F,Q,R,Qf,xf)
        X, U, J = forwardpass(X,U,f,J_prev,K,l,v1,v2)

        if abs(J-J_prev) < eps
          println("-----SOLVED-----")
          println("eps criteria met at iteration: $i")
          break
        end
        J_prev = copy(J)
    end
    
    return X, U
end
# Out:
# solve (generic function with 3 methods)

# %%
X, U = solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,control_init="random");
# Out:
# initial control: random
# Initial Cost: 204.5770428118742
#
# *** Iteration: 1 ***
# New cost: 138.41550393571168
# - Expected improvement: 104.19689134170443
# - Actual improvement: 66.16153887616252
# - (z = 0.6349665333027225)
#
# *** Iteration: 2 ***
# New cost: 117.47827039440376
# - Expected improvement: 31.405240052655714
# - Actual improvement: 20.93723354130792
# - (z = 0.6666796211779763)
#
# *** Iteration: 3 ***
# New cost: 108.88457934885935
# - Expected improvement: 12.170344951548927
# - Actual improvement: 8.593691045544418
# - (z = 0.7061172941076492)
#
# *** Iteration: 4 ***
# New cost: 101.30438572331023
# - Expected improvement: 14.97602172086949
# - Actual improvement: 7.580193625549114
# - (z = 0.5061553573327094)
#
# *** Iteration: 5 ***
# New cost: 96.8779447912589
# - Expected improvement: 8.016149864997322
# - Actual improvement: 4.426440932051335
# - (z = 0.5521903914720304)
#
# *** Iteration: 6 ***
# New cost: 94.30290982311072
# - Expected improvement: 4.121834458331924
# - Actual improvement: 2.5750349681481737
# - (z = 0.6247303219426894)
#
# *** Iteration: 7 ***
# New cost: 92.4174769027768
# - Expected improvement: 2.932050484860103
# - Actual improvement: 1.8854329203339262
# - (z = 0.6430424476213907)
#
# *** Iteration: 8 ***
# New cost: 90.93592262576347
# - Expected improvement: 2.2690240962834305
# - Actual improvement: 1.4815542770133305
# - (z = 0.6529477934765243)
#
# *** Iteration: 9 ***
# New cost: 89.7196006668518
# - Expected improvement: 1.8462770216808342
# - Actual improvement: 1.2163219589116636
# - (z = 0.6587971060834278)
#
# *** Iteration: 10 ***
# New cost: 88.68955943791437
# - Expected improvement: 1.5536551238273029
# - Actual improvement: 1.030041228937435
# - (z = 0.6629793273554895)
#
# *** Iteration: 11 ***
# New cost: 87.79451342226389
# - Expected improvement: 1.342951862959457
# - Actual improvement: 0.8950460156504789
# - (z = 0.6664766179169446)
#
# *** Iteration: 12 ***
# New cost: 86.99811638608587
# - Expected improvement: 1.1890154514647406
# - Actual improvement: 0.7963970361780213
# - (z = 0.6697953632115923)
#
# *** Iteration: 13 ***
# New cost: 86.27281071506921
# - Expected improvement: 1.0774020459715181
# - Actual improvement: 0.7253056710166561
# - (z = 0.6731987132645839)
#
# *** Iteration: 14 ***
# New cost: 85.59645682384674
# - Expected improvement: 0.9993001972186749
# - Actual improvement: 0.676353891222476
# - (z = 0.6768275370153568)
#
# *** Iteration: 15 ***
# New cost: 84.95022550233492
# - Expected improvement: 0.9492909792780835
# - Actual improvement: 0.6462313215118201
# - (z = 0.6807515668201818)
#
# *** Iteration: 16 ***
# New cost: 84.31711048512045
# - Expected improvement: 0.9242676610177087
# - Actual improvement: 0.6331150172144646
# - (z = 0.6849909868287973)
#
# *** Iteration: 17 ***
# New cost: 83.68076369070873
# - Expected improvement: 0.9228840999428867
# - Actual improvement: 0.6363467944117218
# - (z = 0.6895197289140669)
#
# *** Iteration: 18 ***
# New cost: 83.02452701470663
# - Expected improvement: 0.94523910930347
# - Actual improvement: 0.656236676002095
# - (z = 0.6942546806867357)
#
# *** Iteration: 19 ***
# New cost: 82.33066461967601
# - Expected improvement: 0.9926055974499894
# - Actual improvement: 0.6938623950306209
# - (z = 0.6990313139611122)
#
# *** Iteration: 20 ***
# New cost: 81.5799679411116
# - Expected improvement: 1.0669877126655036
# - Actual improvement: 0.7506966785644096
# - (z = 0.7035663763072312)
#
# *** Iteration: 21 ***
# New cost: 80.7521731479462
# - Expected improvement: 1.1701698638754192
# - Actual improvement: 0.8277947931654097
# - (z = 0.7074142128595613)
#
# *** Iteration: 22 ***
# New cost: 79.82800105190005
# - Expected improvement: 1.3017611936444498
# - Actual improvement: 0.9241720960461492
# - (z = 0.7099398112020909)
#
# *** Iteration: 23 ***
# New cost: 78.79387909161865
# - Expected improvement: 1.4557697953753153
# - Actual improvement: 1.0341219602813965
# - (z = 0.7103609125334183)
#
# *** Iteration: 24 ***
# New cost: 77.64979857552866
# - Expected improvement: 1.6160820508041542
# - Actual improvement: 1.1440805160899856
# - (z = 0.7079346717084674)
#
# *** Iteration: 25 ***
# New cost: 76.41819893176758
# - Expected improvement: 1.7536236769433173
# - Actual improvement: 1.2315996437610863
# - (z = 0.7023169565706631)
#
# *** Iteration: 26 ***
# New cost: 75.14770232437414
# - Expected improvement: 1.8308478002403104
# - Actual improvement: 1.27049660739344
# - (z = 0.6939389539789595)
#
# *** Iteration: 27 ***
# New cost: 73.90475481968214
# - Expected improvement: 1.8170247032652038
# - Actual improvement: 1.2429475046919976
# - (z = 0.6840564701505785)
#
# *** Iteration: 28 ***
# New cost: 72.75409708377359
# - Expected improvement: 1.7064644876707185
# - Actual improvement: 1.1506577359085526
# - (z = 0.6742933967991164)
#
# *** Iteration: 29 ***
# New cost: 71.7396390389061
# - Expected improvement: 1.5232101670328324
# - Actual improvement: 1.0144580448674816
# - (z = 0.6660000483345088)
#
# *** Iteration: 30 ***
# New cost: 70.87711414173764
# - Expected improvement: 1.3070353554244558
# - Actual improvement: 0.8625248971684698
# - (z = 0.6599093846917151)
#
# *** Iteration: 31 ***
# New cost: 70.15910019264207
# - Expected improvement: 1.0942111554290341
# - Actual improvement: 0.7180139490955639
# - (z = 0.6561932269956018)
#
# *** Iteration: 32 ***
# New cost: 69.56516902574681
# - Expected improvement: 0.9071900389139571
# - Actual improvement: 0.5939311668952598
# - (z = 0.654693219081511)
#
# *** Iteration: 33 ***
# New cost: 69.07069026353757
# - Expected improvement: 0.754786607529975
# - Actual improvement: 0.4944787622092406
# - (z = 0.655123921484793)
#
# *** Iteration: 34 ***
# New cost: 68.65201634342343
# - Expected improvement: 0.637066419149214
# - Actual improvement: 0.41867392011414495
# - (z = 0.6571903769049282)
#
# *** Iteration: 35 ***
# New cost: 68.28856402203593
# - Expected improvement: 0.5501516465216428
# - Actual improvement: 0.3634523213874985
# - (z = 0.6606402501663701)
#
# *** Iteration: 36 ***
# New cost: 67.96303136528105
# - Expected improvement: 0.4893165198002669
# - Actual improvement: 0.32553265675487353
# - (z = 0.6652803320185308)
#
# *** Iteration: 37 ***
# New cost: 67.66071880796855
# - Expected improvement: 0.4505565161000822
# - Actual improvement: 0.3023125573125043
# - (z = 0.6709758853989175)
#
# *** Iteration: 38 ***
# New cost: 67.36847557974036
# - Expected improvement: 0.43126557606068716
# - Actual improvement: 0.2922432282281875
# - (z = 0.6776409814519102)
#
# *** Iteration: 39 ***
# New cost: 67.07345414233095
# - Expected improvement: 0.4305492283959187
# - Actual improvement: 0.29502143740941733
# - (z = 0.68522114999153)
#
# *** Iteration: 40 ***
# New cost: 66.76164399836782
# - Expected improvement: 0.4495119427038683
# - Actual improvement: 0.3118101439631289
# - (z = 0.6936637591596643)
#
# *** Iteration: 41 ***
# New cost: 66.41603149743008
# - Expected improvement: 0.49172068057187457
# - Actual improvement: 0.3456125009377331
# - (z = 0.7028634641434713)
#
# *** Iteration: 42 ***
# New cost: 66.01420133075223
# - Expected improvement: 0.5639274773257485
# - Actual improvement: 0.4018301666778541
# - (z = 0.7125564595352034)
#
# *** Iteration: 43 ***
# New cost: 65.52543899559073
# - Expected improvement: 0.6768474790897926
# - Actual improvement: 0.48876233516149625
# - (z = 0.7221159127589151)
#
# *** Iteration: 44 ***
# New cost: 64.90856684382024
# - Expected improvement: 0.8448192730486472
# - Actual improvement: 0.6168721517704938
# - (z = 0.730182385096904)
#
# *** Iteration: 45 ***
# New cost: 64.11546140585124
# - Expected improvement: 1.0803533247022967
# - Actual improvement: 0.7931054379690039
# - (z = 0.7341167188869001)
#
# *** Iteration: 46 ***
# New cost: 63.11292468891058
# - Expected improvement: 1.3740561840284626
# - Actual improvement: 1.0025367169406536
# - (z = 0.729618430886438)
#
# *** Iteration: 47 ***
# New cost: 61.93775871172683
# - Expected improvement: 1.6510143329621827
# - Actual improvement: 1.1751659771837524
# - (z = 0.7117842369516668)
#
# *** Iteration: 48 ***
# New cost: 60.755350709425805
# - Expected improvement: 1.7409103383951319
# - Actual improvement: 1.182408002301024
# - (z = 0.6791894885241669)
#
# *** Iteration: 49 ***
# New cost: 59.80399663163047
# - Expected improvement: 1.4906482148369333
# - Actual improvement: 0.9513540777953367
# - (z = 0.6382150183565666)
#
# *** Iteration: 50 ***
# New cost: 59.20881318797942
# - Expected improvement: 0.9923034753491202
# - Actual improvement: 0.5951834436510453
# - (z = 0.5997998177338268)
#
# *** Iteration: 51 ***
# New cost: 58.91120251589799
# - Expected improvement: 0.5213656626917258
# - Actual improvement: 0.2976106720814329
# - (z = 0.5708290617853842)
#
# *** Iteration: 52 ***
# New cost: 58.78508049342424
# - Expected improvement: 0.22859832256225
# - Actual improvement: 0.12612202247375137
# - (z = 0.5517189324055818)
#
# *** Iteration: 53 ***
# New cost: 58.737099749231724
# - Expected improvement: 0.08885959414853972
# - Actual improvement: 0.047980744192514635
# - (z = 0.5399613249674416)
#
# *** Iteration: 54 ***
# New cost: 58.72000846666814
# - Expected improvement: 0.032067882044626655
# - Actual improvement: 0.01709128256358383
# - (z = 0.5329719792469947)
#
# *** Iteration: 55 ***
# New cost: 58.71415207191016
# - Expected improvement: 0.011072970204029718
# - Actual improvement: 0.005856394757977057
# - (z = 0.5288910427886616)
#
# *** Iteration: 56 ***
# New cost: 58.71219005994007
# - Expected improvement: 0.003726291412465859
# - Actual improvement: 0.001962011970093158
# - (z = 0.5265320805370948)
#
# *** Iteration: 57 ***
# New cost: 58.71154121934287
# - Expected improvement: 0.0012354717194210474
# - Actual improvement: 0.0006488405972007172
# - (z = 0.525176405903301)
#
# *** Iteration: 58 ***
# New cost: 58.711328237092275
# - Expected improvement: 0.00040614468155042893
# - Actual improvement: 0.0002129822505949619
# - (z = 0.5243999497467677)
#
# *** Iteration: 59 ***
# New cost: 58.711258622415784
# - Expected improvement: 0.00013286356382552516
# - Actual improvement: 6.961467649091446e-5
# - (z = 0.5239561132225207)
#
# *** Iteration: 60 ***
# New cost: 58.711235923626234
# - Expected improvement: 4.334289227430354e-5
# - Actual improvement: 2.2698789550190668e-5
# - (z = 0.5237026963160918)
#
# *** Iteration: 61 ***
# New cost: 58.71122853264323
# - Expected improvement: 1.4116834463249918e-5
# - Actual improvement: 7.390983000732376e-6
# - (z = 0.5235580979555423)
#
# -----SOLVED-----
# eps criteria met at iteration: 61

# %%
P = plot(linspace(0,tf,size(X,2)),X[1,:])
P = plot!(linspace(0,tf,size(X,2)),X[2,:])

# %%
W = plot(linspace(0,tf,size(X,2)),[U[1,:]; U[1,end]],title="Pendulum",ylabel="Control")

# %%
plt = plot()
@gif for i=1:size(X,2)
    x = cos(X[1,i] - pi/2)
    y = sin(X[1,i] - pi/2)
    plt = plot([0,x],[0,y],xlims=(-1.5,1.5),ylims=(-1.5,1.5),color="black",size=(200,200),label="",title="Pendulum")
end
