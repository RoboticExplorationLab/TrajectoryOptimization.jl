# %%
using ForwardDiff
using Plots

# %%
## Simple Pendulum
n = 2 # number of states 
m = 1 # number of controls

#initial and goal conditions
x0 = [0.; 0.]
xf = [pi; 0.] # (ie, swing up)

#costs
Q = 0.3*eye(n)
Qf = 30.0*eye(n)
R = 0.3*eye(m)

#simulation
dt = 0.1
tf = 5.
# Out:
# 5.0

# %%
# Dynamics 
function fc(x,u)
    # continuous dynamics (as defined in https://github.com/HarvardAgileRoboticsLab/unscented-dynamic-programming/blob/master/pendulum_dynamics.m)
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (u - m*g*lc*sin(x[1]) - b*x[2])];
end

function f(x,u,dt)
    # RK4
    k1 = dt*fc(x,u)
    k2 = dt*fc(x + k1/2,u)
    k3 = dt*fc(x + k2/2,u)
    k4 = dt*fc(x + k3, u)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

function fc_aug(x)
    # augmented continuous dynamics
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (x[3] - m*g*lc*sin(x[1]) - b*x[2]); 0.0; 0.0];
end

function f2_aug(x)
    # RK4
    k1 = x[4]*fc_aug(x)
    k2 = x[4]*fc_aug(x + k1/2)
    k3 = x[4]*fc_aug(x + k2/2)
    k4 = x[4]*fc_aug(x + k3)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

F = x-> ForwardDiff.jacobian(f2_aug,x)
# Out:
# (::#47) (generic function with 1 method)

# %%
#iLQR
function rollout(x0,U,f,dt,tf)
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    X[:,1] = x0
    for k = 1:N-1
      X[:,k+1] = f(X[:,k],U[:,k],dt)
    end
    return X
end

function cost(X,U,Q,R,Qf,xf)
    N = size(X,2)
    J = 0.0
    for k = 1:N-1
      J += 0.5*(X[:,k] - xf)'*Q*(X[:,k] - xf) + 0.5*U[:,k]'*R*U[:,k]
    end
    J += 0.5*(X[:,N] - xf)'*Qf*(X[:,N] - xf)
    return J
end

function backwardpass(X,U,F,Q,R,Qf,xf)
    n, N = size(X)
    m = size(U,1)
    
    S = zeros(n,n,N)
    s = zeros(n,N)
    
    Qx = zeros(n,1,N)
    Qu = zeros(m,1,N)
    Qxx = zeros(n,n,N)
    Quu = zeros(m,m,N)
    Qux = zeros(m,n,N)
    
    K = zeros(m,n,N-1)
    l = zeros(m,N-1)
    
    S[:,:,N] = Qf
    s[:,N] = Qf*(X[:,N] - xf)
    v1 = 0.0
    v2 = 0.0

    mu = 0.0
    k = N-1
    
    while k >= 1
        q = Q*(X[:,k] - xf)
        r = R*(U[:,k])
        F_aug = F([X[:,k];U[:,k];dt])
        fx = F_aug[1:size(X,1),1:size(X,1)]
        fu = F_aug[1:size(X,1),size(X,1)+1:size(X,1)+size(U,1)]
        
        Qx[:,:,k] = q + fx'*s[:,k+1]
        Qu[:,:,k] = r + fu'*s[:,k+1]
        Qxx[:,:,k] = Q + fx'*S[:,:,k+1]*fx
        Quu[:,:,k] = R + fu'*(S[:,:,k+1] + mu*eye(n))*fu
        Qux[:,:,k] = fu'*(S[:,:,k+1] + mu*eye(n))*fx

        # regularization        
        if any(x->x < 0.0, (eigvals(Quu[:,:,k])))
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end
        
        K[:,:,k] = Quu[:,:,k]\Qux[:,:,k]
        l[:,k] = Quu[:,:,k]\Qu[:,:,k]
        s[:,k] = (Qx[:,:,k]' - Qu[:,:,k]'*K[:,:,k] + l[:,k]'*Quu[:,:,k]*K[:,:,k] - l[:,k]'*Qux[:,:,k])'
        S[:,:,k] = Qxx[:,:,k] + K[:,:,k]'*Quu[:,:,k]*K[:,:,k] - K[:,:,k]'*Qux[:,:,k] - Qux[:,:,k]'*K[:,:,k]

        # terms for line search
        v1 += l[:,k]'*Qu[:,:,k]
        v2 += l[:,k]'*Quu[:,:,k]*l[:,k]
        
        k = k - 1;
    end
    return K, l, v1, v2
end

function forwardpass(X,U,f,J,K,l,v1,v2,c1=0.0,c2=1.0)
    N = size(X,2)
    m = size(U,1)
    X_prev = copy(X)
    J_prev = copy(J)
    U_ = zeros(m,N-1)
    J = Inf
    dV = 0.0
    dJ = 0.0
    z = 0.0
    
    alpha = 1.0

    while J > J_prev || z < c1 || z > c2 
        for k = 1:N-1
          U_[:,k] = U[:,k] - K[:,:,k]*(X[:,k] - X_prev[:,k]) - alpha*l[:,k]
          X[:,k+1] = f(X[:,k],U_[:,k],dt);
        end

        J = cost(X,U_,Q,R,Qf,xf)
        
        dV = alpha*v1 + (alpha^2)*v2/2.0
        dJ = J_prev - J
        z = dJ/dV[1]

        alpha = alpha/2.0;
    end

    println("New cost: $J")
    println("- Expected improvement: $(dV[1])")
    println("- Actual improvement: $(dJ)")
    println("- (z = $z)\n")
    
    return X, U_, J
end

function solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,control_init="zeros",iterations=100,eps=1e-5,)
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    
    if control_init == "random"
        U = rand(m,N-1)
    else
        U = zeros(m,N-1)
    end
        
    X = rollout(x0,U,f,dt,tf)
    J_prev = cost(X,U,Q,R,Qf,xf)
    println("Initial Cost: $J_prev\n")
    
    for i = 1:iterations
        println("*** Iteration: $i ***")
        K, l, v1, v2 = backwardpass(X,U,F,Q,R,Qf,xf)
        X, U, J = forwardpass(X,U,f,J_prev,K,l,v1,v2)

        if abs(J-J_prev) < eps
          println("-----SOLVED-----")
          println("eps criteria met at iteration: $i")
          break
        end
        J_prev = copy(J)
    end
    
    return X, U
end
# Out:
# solve (generic function with 4 methods)

# %%
X, U = solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,control_init="random");
# Out:
# Initial Cost: 202.87596094120732
#
# *** Iteration: 1 ***
# New cost: 132.99939449317432
# - Expected improvement: 244.1095209923873
# - Actual improvement: 69.876566448033
# - (z = 0.2862508851107538)
#
# *** Iteration: 2 ***
# New cost: 103.31526006732445
# - Expected improvement: 78.65300097535732
# - Actual improvement: 29.684134425849876
# - (z = 0.377406253515364)
#
# *** Iteration: 3 ***
# New cost: 98.05013052674
# - Expected improvement: 9.641633844765261
# - Actual improvement: 5.265129540584439
# - (z = 0.5460827101874481)
#
# *** Iteration: 4 ***
# New cost: 95.08396690039145
# - Expected improvement: 4.852546336211988
# - Actual improvement: 2.9661636263485605
# - (z = 0.6112592071947153)
#
# *** Iteration: 5 ***
# New cost: 93.00828872446324
# - Expected improvement: 3.251747755040139
# - Actual improvement: 2.0756781759282035
# - (z = 0.6383269344034903)
#
# *** Iteration: 6 ***
# New cost: 91.40850906603501
# - Expected improvement: 2.4606188910733886
# - Actual improvement: 1.5997796584282327
# - (z = 0.6501533676067834)
#
# *** Iteration: 7 ***
# New cost: 90.11222226953359
# - Expected improvement: 1.9728562704898922
# - Actual improvement: 1.2962867965014198
# - (z = 0.6570609404706055)
#
# *** Iteration: 8 ***
# New cost: 89.02514849969651
# - Expected improvement: 1.642952335313685
# - Actual improvement: 1.087073769837076
# - (z = 0.6616587386447359)
#
# *** Iteration: 9 ***
# New cost: 88.08851898774658
# - Expected improvement: 1.4077942789791729
# - Actual improvement: 0.9366295119499313
# - (z = 0.6653170324211751)
#
# *** Iteration: 10 ***
# New cost: 87.26177467630298
# - Expected improvement: 1.2364223405662609
# - Actual improvement: 0.8267443114436048
# - (z = 0.6686585031009467)
#
# *** Iteration: 11 ***
# New cost: 86.51482093782101
# - Expected improvement: 1.1115179377556133
# - Actual improvement: 0.7469537384819631
# - (z = 0.6720123113714374)
#
# *** Iteration: 12 ***
# New cost: 85.8239440323022
# - Expected improvement: 1.0226833478954107
# - Actual improvement: 0.6908769055188202
# - (z = 0.6755530995401284)
#
# *** Iteration: 13 ***
# New cost: 85.1693706587248
# - Expected improvement: 0.9634985537624576
# - Actual improvement: 0.6545733735773922
# - (z = 0.6793714126723761)
#
# *** Iteration: 14 ***
# New cost: 84.53361336135134
# - Expected improvement: 0.9301452262740701
# - Actual improvement: 0.6357572973734591
# - (z = 0.6835032631626184)
#
# *** Iteration: 15 ***
# New cost: 83.90021624792742
# - Expected improvement: 0.9207170148068983
# - Actual improvement: 0.6333971134239249
# - (z = 0.6879389684753107)
#
# *** Iteration: 16 ***
# New cost: 83.2527256557871
# - Expected improvement: 0.9348464934437829
# - Actual improvement: 0.6474905921403149
# - (z = 0.6926170196724943)
#
# *** Iteration: 17 ***
# New cost: 82.57384437444883
# - Expected improvement: 0.9734399404009529
# - Actual improvement: 0.6788812813382776
# - (z = 0.6974043833239997)
#
# *** Iteration: 18 ***
# New cost: 81.84487546984259
# - Expected improvement: 1.0383235384177087
# - Actual improvement: 0.7289689046062335
# - (z = 0.7020633527359904)
#
# *** Iteration: 19 ***
# New cost: 81.0457900261936
# - Expected improvement: 1.1315147993550645
# - Actual improvement: 0.7990854436489911
# - (z = 0.7062085658132357)
#
# *** Iteration: 20 ***
# New cost: 80.15659645546398
# - Expected improvement: 1.253674103676186
# - Actual improvement: 0.889193570729617
# - (z = 0.7092701110457719)
#
# *** Iteration: 21 ***
# New cost: 79.16103131760146
# - Expected improvement: 1.4012097174843712
# - Actual improvement: 0.9955651378625276
# - (z = 0.7105040205187072)
#
# *** Iteration: 22 ***
# New cost: 78.05340024797195
# - Expected improvement: 1.5619767870985009
# - Actual improvement: 1.1076310696295053
# - (z = 0.7091213382799499)
#
# *** Iteration: 23 ***
# New cost: 76.84760089638208
# - Expected improvement: 1.7113400039997275
# - Actual improvement: 1.2057993515898744
# - (z = 0.7045936802573958)
#
# *** Iteration: 24 ***
# New cost: 75.58351725075309
# - Expected improvement: 1.8134585109536991
# - Actual improvement: 1.2640836456289861
# - (z = 0.6970568325625512)
#
# *** Iteration: 25 ***
# New cost: 74.32328332488736
# - Expected improvement: 1.83303672351689
# - Actual improvement: 1.2602339258657338
# - (z = 0.6875115537499059)
#
# *** Iteration: 26 ***
# New cost: 73.13470637956631
# - Expected improvement: 1.7542792150580757
# - Actual improvement: 1.1885769453210457
# - (z = 0.6775300847885254)
#
# *** Iteration: 27 ***
# New cost: 72.07039006623812
# - Expected improvement: 1.5918168090785119
# - Actual improvement: 1.0643163133281917
# - (z = 0.6686173353982325)
#
# *** Iteration: 28 ***
# New cost: 71.15566629153534
# - Expected improvement: 1.3823248849795875
# - Actual improvement: 0.9147237747027788
# - (z = 0.6617285014848635)
#
# *** Iteration: 29 ***
# New cost: 70.38999081238767
# - Expected improvement: 1.1650484195600752
# - Actual improvement: 0.7656754791476743
# - (z = 0.6572048562898313)
#
# *** Iteration: 30 ***
# New cost: 69.75624510727151
# - Expected improvement: 0.9675884817062175
# - Actual improvement: 0.633745705116155
# - (z = 0.6549744205290934)
#
# *** Iteration: 31 ***
# New cost: 69.23046661759682
# - Expected improvement: 0.8029876355590734
# - Actual improvement: 0.5257784896746927
# - (z = 0.6547778152382431)
#
# *** Iteration: 32 ***
# New cost: 68.78830561141011
# - Expected improvement: 0.673702553630859
# - Actual improvement: 0.4421610061867085
# - (z = 0.6563148733869595)
#
# *** Iteration: 33 ***
# New cost: 68.40803504860075
# - Expected improvement: 0.5767656874322127
# - Actual improvement: 0.38027056280935767
# - (z = 0.6593155090455184)
#
# *** Iteration: 34 ***
# New cost: 68.07127483780343
# - Expected improvement: 0.5075009220451463
# - Actual improvement: 0.33676021079732266
# - (z = 0.6635657122360167)
#
# *** Iteration: 35 ***
# New cost: 67.76253988486725
# - Expected improvement: 0.4615483315999619
# - Actual improvement: 0.30873495293617736
# - (z = 0.6689114266017268)
#
# *** Iteration: 36 ***
# New cost: 67.46828028903404
# - Expected improvement: 0.4357777557553716
# - Actual improvement: 0.2942595958332106
# - (z = 0.6752515288972123)
#
# *** Iteration: 37 ***
# New cost: 67.17569632201626
# - Expected improvement: 0.428679811616867
# - Actual improvement: 0.29258396701777656
# - (z = 0.6825233171448571)
#
# *** Iteration: 38 ***
# New cost: 66.87136031271837
# - Expected improvement: 0.44063368835564176
# - Actual improvement: 0.3043360092978986
# - (z = 0.6906780333424363)
#
# *** Iteration: 39 ***
# New cost: 66.53952660148882
# - Expected improvement: 0.4742941322952625
# - Actual improvement: 0.3318337112295495
# - (z = 0.6996369734192135)
#
# *** Iteration: 40 ***
# New cost: 66.15993985773038
# - Expected improvement: 0.5352266974371706
# - Actual improvement: 0.3795867437584377
# - (z = 0.7092074172981567)
#
# *** Iteration: 41 ***
# New cost: 65.70506106292058
# - Expected improvement: 0.6327262160839985
# - Actual improvement: 0.454878794809801
# - (z = 0.7189188360569098)
#
# *** Iteration: 42 ***
# New cost: 65.13736083230404
# - Expected improvement: 0.7801111933083107
# - Actual improvement: 0.5677002306165377
# - (z = 0.7277170683951137)
#
# *** Iteration: 43 ***
# New cost: 64.40992695431531
# - Expected improvement: 0.9917735412583027
# - Actual improvement: 0.7274338779887302
# - (z = 0.7334677199250604)
#
# *** Iteration: 44 ***
# New cost: 63.48007365971687
# - Expected improvement: 1.2695403501779325
# - Actual improvement: 0.9298532945984377
# - (z = 0.7324330372548726)
#
# *** Iteration: 45 ***
# New cost: 62.35251228040889
# - Expected improvement: 1.5668765734697963
# - Actual improvement: 1.1275613793079842
# - (z = 0.7196236119677486)
#
# *** Iteration: 46 ***
# New cost: 61.14614222554092
# - Expected improvement: 1.7438177918419369
# - Actual improvement: 1.2063700548679677
# - (z = 0.6917982260025682)
#
# *** Iteration: 47 ***
# New cost: 60.09194395055111
# - Expected improvement: 1.6155990401724738
# - Actual improvement: 1.0541982749898082
# - (z = 0.6525123182032015)
#
# *** Iteration: 48 ***
# New cost: 59.37339926607538
# - Expected improvement: 1.1739122139080012
# - Actual improvement: 0.7185446844757308
# - (z = 0.612094052658049)
#
# *** Iteration: 49 ***
# New cost: 58.98767532685631
# - Expected improvement: 0.6655405965015743
# - Actual improvement: 0.3857239392190692
# - (z = 0.5795648548663054)
#
# *** Iteration: 50 ***
# New cost: 58.81589033953156
# - Expected improvement: 0.3082479115882733
# - Actual improvement: 0.17178498732474878
# - (z = 0.5572948943582852)
#
# *** Iteration: 51 ***
# New cost: 58.74845502388388
# - Expected improvement: 0.12411334365863727
# - Actual improvement: 0.06743531564768546
# - (z = 0.5433365475444792)
#
# *** Iteration: 52 ***
# New cost: 58.72397732892651
# - Expected improvement: 0.045755968087606014
# - Actual improvement: 0.024477694957369067
# - (z = 0.5349617979998411)
#
# *** Iteration: 53 ***
# New cost: 58.71549700649468
# - Expected improvement: 0.015999172729479833
# - Actual improvement: 0.00848032243182928
# - (z = 0.5300475577842575)
#
# *** Iteration: 54 ***
# New cost: 58.712637757277996
# - Expected improvement: 0.0054234740560934165
# - Actual improvement: 0.002859249216683679
# - (z = 0.5271988373340215)
#
# *** Iteration: 55 ***
# New cost: 58.711688728340945
# - Expected improvement: 0.0018057514845342781
# - Actual improvement: 0.0009490289370504001
# - (z = 0.5255589958964727)
#
# *** Iteration: 56 ***
# New cost: 58.71137655478395
# - Expected improvement: 0.0005950482699068786
# - Actual improvement: 0.00031217355699197924
# - (z = 0.5246188801470383)
#
# *** Iteration: 57 ***
# New cost: 58.71127439631269
# - Expected improvement: 0.00019492871066056292
# - Actual improvement: 0.00010215847126460176
# - (z = 0.5240811931624293)
#
# *** Iteration: 58 ***
# New cost: 58.711241063368924
# - Expected improvement: 6.36399247464954e-5
# - Actual improvement: 3.333294376517415e-5
# - (z = 0.52377409146779)
#
# *** Iteration: 59 ***
# New cost: 58.71123020554326
# - Expected improvement: 2.0736917416031915e-5
# - Actual improvement: 1.0857825664345455e-5
# - (z = 0.5235988284329648)
#
# *** Iteration: 60 ***
# New cost: 58.71122667212105
# - Expected improvement: 6.749627358610673e-6
# - Actual improvement: 3.5334222090455114e-6
# - (z = 0.5234988572425163)
#
# -----SOLVED-----
# eps criteria met at iteration: 60

# %%
P = plot(linspace(0,tf,size(X,2)),X[1,:])
P = plot!(linspace(0,tf,size(X,2)),X[2,:])

# %%
plt = plot()
@gif for i=1:size(X,2)
    x = cos(X[1,i] - pi/2)
    y = sin(X[1,i] - pi/2)
    plt = plot([0,x],[0,y],xlims=(-1.5,1.5),ylims=(-1.5,1.5),color="black",size=(200,200),label="",title="Pendulum")
end
# Out:
# INFO: Saved animation to C:\Users\taylor howell\Google Drive\Stanford\Research-Manchester\iLQR demos\tmp.gif
# Plots.AnimatedGif("C:\\Users\\taylor howell\\Google Drive\\Stanford\\Research-Manchester\\iLQR demos\\tmp.gif")
