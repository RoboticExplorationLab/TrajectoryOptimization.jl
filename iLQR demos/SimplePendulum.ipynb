# %%
using ForwardDiff
using Plots

# %%
## Simple Pendulum
n = 2 # number of states 
m = 1 # number of controls

#initial and goal conditions
x0 = [0.; 0.]
xf = [pi; 0.] # (ie, swing up)

#costs
Q = 0.3*eye(n)
Qf = 30.0*eye(n)
R = 0.3*eye(m)

#simulation
dt = 0.1
tf = 5.0
# Out:
# 5.0

# %%
# Dynamics 
function fc(x,u)
    # continuous dynamics (as defined in https://github.com/HarvardAgileRoboticsLab/unscented-dynamic-programming/blob/master/pendulum_dynamics.m)
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (u - m*g*lc*sin(x[1]) - b*x[2])];
end

function f(x,u,dt)
    # RK4
    k1 = dt*fc(x,u)
    k2 = dt*fc(x + k1/2,u)
    k3 = dt*fc(x + k2/2,u)
    k4 = dt*fc(x + k3, u)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

function fc_aug(S)
    # augmented continuous dynamics
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [S[2]; (S[3] - m*g*lc*sin(S[1]) - b*S[2]); 0.0; 0.0];
end

function f2_aug(S)
    # RK4
    k1 = S[4]*fc_aug(S)
    k2 = S[4]*fc_aug(S + k1/2)
    k3 = S[4]*fc_aug(S + k2/2)
    k4 = S[4]*fc_aug(S + k3)
    return S + (k1 + 2*k2 + 2*k3 + k4)/6
end

F = S-> ForwardDiff.jacobian(f2_aug,S)
# Out:
# (::#1) (generic function with 1 method)

# %%
#iLQR
function rollout(x0,U,f,dt,tf)
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    X[:,1] = x0
    for k = 1:N-1
      X[:,k+1] = f(X[:,k],U[:,k],dt)
    end
    return X
end

function cost(X,U,Q,R,Qf,xf)
    N = size(X,2)
    J = 0.0
    for k = 1:N-1
      J += 0.5*(X[:,k] - xf)'*Q*(X[:,k] - xf) + 0.5*U[:,k]'*R*U[:,k]
    end
    J += 0.5*(X[:,N] - xf)'*Qf*(X[:,N] - xf)
    return J
end

function backwardpass(X,U,F,Q,R,Qf,xf)
    n, N = size(X)
    m = size(U,1)
    
    S = zeros(n,n,N)
    s = zeros(n,N)
    
    Qx = zeros(n,1,N)
    Qu = zeros(m,1,N)
    Qxx = zeros(n,n,N)
    Quu = zeros(m,m,N)
    Qux = zeros(m,n,N)
    
    K = zeros(m,n,N-1)
    l = zeros(m,N-1)
    
    S[:,:,N] = Qf
    s[:,N] = Qf*(X[:,N] - xf)
    v1 = 0.0
    v2 = 0.0

    mu = 0.0
    k = N-1
    
    while k >= 1
        q = Q*(X[:,k] - xf)
        r = R*(U[:,k])
        F_aug = F([X[:,k];U[:,k];dt])
        fx = F_aug[1:size(X,1),1:size(X,1)]
        fu = F_aug[1:size(X,1),size(X,1)+1:size(X,1)+size(U,1)]
        
        Qx[:,:,k] = q + fx'*s[:,k+1]
        Qu[:,:,k] = r + fu'*s[:,k+1]
        Qxx[:,:,k] = Q + fx'*S[:,:,k+1]*fx
        Quu[:,:,k] = R + fu'*(S[:,:,k+1] + mu*eye(n))*fu
        Qux[:,:,k] = fu'*(S[:,:,k+1] + mu*eye(n))*fx

        # regularization        
        if any(x->x < 0.0, (eigvals(Quu[:,:,k])))
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end
        
        K[:,:,k] = Quu[:,:,k]\Qux[:,:,k]
        l[:,k] = Quu[:,:,k]\Qu[:,:,k]
        s[:,k] = (Qx[:,:,k]' - Qu[:,:,k]'*K[:,:,k] + l[:,k]'*Quu[:,:,k]*K[:,:,k] - l[:,k]'*Qux[:,:,k])'
        S[:,:,k] = Qxx[:,:,k] + K[:,:,k]'*Quu[:,:,k]*K[:,:,k] - K[:,:,k]'*Qux[:,:,k] - Qux[:,:,k]'*K[:,:,k]

        # terms for line search
        v1 += l[:,k]'*Qu[:,:,k]
        v2 += l[:,k]'*Quu[:,:,k]*l[:,k]
        
        k = k - 1;
    end
    return K, l, v1, v2
end

function forwardpass(X,U,f,J,K,l,v1,v2,c1=0.0,c2=1.0)
    N = size(X,2)
    m = size(U,1)
    X_prev = copy(X)
    J_prev = copy(J)
    U_ = zeros(m,N-1)
    J = Inf
    dV = 0.0
    dJ = 0.0
    z = 0.0
    
    alpha = 1.0

    while J > J_prev || z < c1 || z > c2 
        for k = 1:N-1
          U_[:,k] = U[:,k] - K[:,:,k]*(X[:,k] - X_prev[:,k]) - alpha*l[:,k]
          X[:,k+1] = f(X[:,k],U_[:,k],dt);
        end

        J = cost(X,U_,Q,R,Qf,xf)
        
        dV = alpha*v1 + (alpha^2)*v2/2.0
        dJ = J_prev - J
        z = dJ/dV[1]

        alpha = alpha/2.0;
    end

    println("New cost: $J")
    println("- Expected improvement: $(dV[1])")
    println("- Actual improvement: $(dJ)")
    println("- (z = $z)\n")
    
    return X, U_, J
end

function solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,iterations=100,eps=1e-5;control_init="random")
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    
    if control_init == "random"
        U = 5.0*rand(m,N-1)
    else
        U = zeros(m,N-1)
    end
        
    X = rollout(x0,U,f,dt,tf)
    J_prev = cost(X,U,Q,R,Qf,xf)
    println("Initial Cost: $J_prev\n")
    
    for i = 1:iterations
        println("*** Iteration: $i ***")
        K, l, v1, v2 = backwardpass(X,U,F,Q,R,Qf,xf)
        X, U, J = forwardpass(X,U,f,J_prev,K,l,v1,v2)

        if abs(J-J_prev) < eps
          println("-----SOLVED-----")
          println("eps criteria met at iteration: $i")
          break
        end
        J_prev = copy(J)
    end
    
    return X, U
end
# Out:
# solve (generic function with 3 methods)

# %%
X, U = solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,control_init="random");
# Out:
# Initial Cost: 179.22226513009758
#
# *** Iteration: 1 ***
# New cost: 117.46899906248626
# - Expected improvement: 190.9587206328588
# - Actual improvement: 61.75326606761132
# - (z = 0.3233854199638226)
#
# *** Iteration: 2 ***
# New cost: 100.68199719745867
# - Expected improvement: 42.458215424035956
# - Actual improvement: 16.78700186502759
# - (z = 0.3953770005963163)
#
# *** Iteration: 3 ***
# New cost: 96.72306772077147
# - Expected improvement: 6.803092774371634
# - Actual improvement: 3.958929476687203
# - (z = 0.5819308376333099)
#
# *** Iteration: 4 ***
# New cost: 94.18429077326805
# - Expected improvement: 4.071667377984259
# - Actual improvement: 2.538776947503422
# - (z = 0.6235226780141069)
#
# *** Iteration: 5 ***
# New cost: 92.32776607982392
# - Expected improvement: 2.8824095587537317
# - Actual improvement: 1.856524693444129
# - (z = 0.6440877521398574)
#
# *** Iteration: 6 ***
# New cost: 90.86335540694472
# - Expected improvement: 2.241618906438894
# - Actual improvement: 1.4644106728791968
# - (z = 0.6532826202851784)
#
# *** Iteration: 7 ***
# New cost: 89.65895828591286
# - Expected improvement: 1.8274296589939745
# - Actual improvement: 1.2043971210318603
# - (z = 0.6590661999515197)
#
# *** Iteration: 8 ***
# New cost: 88.63745528996674
# - Expected improvement: 1.5403082871549472
# - Actual improvement: 1.021502995946122
# - (z = 0.6631808738969435)
#
# *** Iteration: 9 ***
# New cost: 87.74864984505909
# - Expected improvement: 1.333221568604902
# - Actual improvement: 0.8888054449076463
# - (z = 0.6666599654832335)
#
# *** Iteration: 10 ***
# New cost: 86.95679605560395
# - Expected improvement: 1.1819105920873916
# - Actual improvement: 0.7918537894551463
# - (z = 0.6699777417652552)
#
# *** Iteration: 11 ***
# New cost: 86.23470477008316
# - Expected improvement: 1.0723215518160758
# - Actual improvement: 0.7220912855207899
# - (z = 0.6733906301685921)
#
# *** Iteration: 12 ***
# New cost: 85.56046446605872
# - Expected improvement: 0.9958731695007232
# - Actual improvement: 0.6742403040244369
# - (z = 0.6770343098634382)
#
# *** Iteration: 13 ***
# New cost: 84.91538035436504
# - Expected improvement: 0.9472941699164878
# - Actual improvement: 0.6450841116936772
# - (z = 0.6809754901695921)
#
# *** Iteration: 14 ***
# New cost: 84.28251022154862
# - Expected improvement: 0.9235853763944494
# - Actual improvement: 0.6328701328164215
# - (z = 0.6852318680997956)
#
# *** Iteration: 15 ***
# New cost: 83.64551250334699
# - Expected improvement: 0.9234866966201314
# - Actual improvement: 0.6369977182016271
# - (z = 0.6897746556966925)
#
# *** Iteration: 16 ***
# New cost: 82.98768771306631
# - Expected improvement: 0.9471686845910943
# - Actual improvement: 0.6578247902806851
# - (z = 0.6945170390263452)
#
# *** Iteration: 17 ***
# New cost: 82.29122477578511
# - Expected improvement: 0.9959585747140758
# - Actual improvement: 0.696462937281197
# - (z = 0.6992890617776354)
#
# *** Iteration: 18 ***
# New cost: 81.53683611295648
# - Expected improvement: 1.0718797660546957
# - Actual improvement: 0.7543886628286316
# - (z = 0.7037997047050675)
#
# *** Iteration: 19 ***
# New cost: 80.70423938725416
# - Expected improvement: 1.1766599726305502
# - Actual improvement: 0.8325967257023166
# - (z = 0.7075933107854063)
#
# *** Iteration: 20 ***
# New cost: 79.77431659397084
# - Expected improvement: 1.3097047587563597
# - Actual improvement: 0.9299227932833247
# - (z = 0.7100247495216709)
#
# *** Iteration: 21 ***
# New cost: 78.73400877698977
# - Expected improvement: 1.464588085146661
# - Actual improvement: 1.0403078169810698
# - (z = 0.7103074424348436)
#
# *** Iteration: 22 ***
# New cost: 77.58431848364384
# - Expected improvement: 1.624522280379581
# - Actual improvement: 1.1496902933459268
# - (z = 0.7077097724244777)
#
# *** Iteration: 23 ***
# New cost: 76.34910672320606
# - Expected improvement: 1.7597574555213131
# - Actual improvement: 1.2352117604377781
# - (z = 0.701921595252942)
#
# *** Iteration: 24 ***
# New cost: 75.07831562959394
# - Expected improvement: 1.8326359086191262
# - Actual improvement: 1.270791093612118
# - (z = 0.6934225656255132)
#
# *** Iteration: 25 ***
# New cost: 73.83886432762274
# - Expected improvement: 1.8133770866931833
# - Actual improvement: 1.2394513019712008
# - (z = 0.683504446519408)
#
# *** Iteration: 26 ***
# New cost: 72.69477645070111
# - Expected improvement: 1.6979842245823153
# - Actual improvement: 1.1440878769216312
# - (z = 0.6737918175906867)
#
# *** Iteration: 27 ***
# New cost: 71.68847764969995
# - Expected improvement: 1.5118535651072318
# - Actual improvement: 1.006298801001165
# - (z = 0.6656059979789054)
#
# *** Iteration: 28 ***
# New cost: 70.8342199541394
# - Expected improvement: 1.2950264870692205
# - Actual improvement: 0.8542576955605483
# - (z = 0.6596449602307535)
#
# *** Iteration: 29 ***
# New cost: 70.12359760797686
# - Expected improvement: 1.0831731262033792
# - Actual improvement: 0.7106223461625376
# - (z = 0.6560561086419618)
#
# *** Iteration: 30 ***
# New cost: 69.5357547837634
# - Expected improvement: 0.8979228614912096
# - Actual improvement: 0.5878428242134675
# - (z = 0.6546696263387457)
#
# *** Iteration: 31 ***
# New cost: 69.04601407172656
# - Expected improvement: 0.747470643365004
# - Actual improvement: 0.4897407120368342
# - (z = 0.655197252740379)
#
# *** Iteration: 32 ***
# New cost: 68.6308641888217
# - Expected improvement: 0.6315551132803722
# - Actual improvement: 0.4151498829048563
# - (z = 0.6573454543792997)
#
# *** Iteration: 33 ***
# New cost: 68.26990747543067
# - Expected improvement: 0.5461883391011979
# - Actual improvement: 0.3609567133910332
# - (z = 0.6608649206700751)
#
# *** Iteration: 34 ***
# New cost: 67.94600697753724
# - Expected improvement: 0.48665438611232154
# - Actual improvement: 0.3239004978934332
# - (z = 0.6655657631711468)
#
# *** Iteration: 35 ***
# New cost: 67.64457723763906
# - Expected improvement: 0.4490130367425102
# - Actual improvement: 0.30142973989818245
# - (z = 0.6713162318960452)
#
# *** Iteration: 36 ***
# New cost: 67.35251789742053
# - Expected improvement: 0.4307452462748974
# - Actual improvement: 0.292059340218529
# - (z = 0.6780326486345936)
#
# *** Iteration: 37 ***
# New cost: 67.05695825364195
# - Expected improvement: 0.43105762368441747
# - Actual improvement: 0.29555964377857435
# - (z = 0.6856615624897454)
#
# *** Iteration: 38 ***
# New cost: 66.74377536426842
# - Expected improvement: 0.4511751883325208
# - Actual improvement: 0.313182889373536
# - (z = 0.6941491852222976)
#
# *** Iteration: 39 ***
# New cost: 66.39572765699995
# - Expected improvement: 0.4948182977028257
# - Actual improvement: 0.34804770726846357
# - (z = 0.7033848765986651)
#
# *** Iteration: 40 ***
# New cost: 65.9900229040056
# - Expected improvement: 0.5689379048996583
# - Actual improvement: 0.40570475299435316
# - (z = 0.7130914454819212)
#
# *** Iteration: 41 ***
# New cost: 65.49541042396736
# - Expected improvement: 0.6844773900358422
# - Actual improvement: 0.4946124800382421
# - (z = 0.7226133211096163)
#
# *** Iteration: 42 ***
# New cost: 64.87014778693674
# - Expected improvement: 0.8558953602486596
# - Actual improvement: 0.625262637030616
# - (z = 0.7305363086078199)
#
# *** Iteration: 43 ***
# New cost: 64.06611056974015
# - Expected improvement: 1.0952172115329997
# - Actual improvement: 0.8040372171965942
# - (z = 0.7341349357276494)
#
# *** Iteration: 44 ***
# New cost: 63.05218797430598
# - Expected improvement: 1.390790819448517
# - Actual improvement: 1.0139225954341669
# - (z = 0.7290259478677119)
#
# *** Iteration: 45 ***
# New cost: 61.87109913321821
# - Expected improvement: 1.662657430710771
# - Actual improvement: 1.181088841087771
# - (z = 0.7103621102411133)
#
# *** Iteration: 46 ***
# New cost: 60.69531064902245
# - Expected improvement: 1.7365873039451025
# - Actual improvement: 1.1757884841957562
# - (z = 0.6770684557722216)
#
# *** Iteration: 47 ***
# New cost: 59.762034634826186
# - Expected improvement: 1.4675253265707195
# - Actual improvement: 0.9332760141962666
# - (z = 0.6359522369383056)
#
# *** Iteration: 48 ***
# New cost: 59.1859439369108
# - Expected improvement: 0.9634564745239556
# - Actual improvement: 0.576090697915383
# - (z = 0.5979415917050428)
#
# *** Iteration: 49 ***
# New cost: 58.90094120334929
# - Expected improvement: 0.5004040304464105
# - Actual improvement: 0.2850027335615124
# - (z = 0.569545239887979)
#
# *** Iteration: 50 ***
# New cost: 58.78103845298508
# - Expected improvement: 0.217644454764502
# - Actual improvement: 0.11990275036421139
# - (z = 0.5509111201291568)
#
# *** Iteration: 51 ***
# New cost: 58.73563018864699
# - Expected improvement: 0.0841710947524511
# - Actual improvement: 0.04540826433809286
# - (z = 0.5394757484340614)
#
# *** Iteration: 52 ***
# New cost: 58.719498928153236
# - Expected improvement: 0.030282826138606406
# - Actual improvement: 0.016131260493750688
# - (z = 0.5326867584919879)
#
# *** Iteration: 53 ***
# New cost: 58.713980203263944
# - Expected improvement: 0.010437786259730845
# - Actual improvement: 0.005518724889292059
# - (z = 0.5287256082818435)
#
# *** Iteration: 54 ***
# New cost: 58.712133001401874
# - Expected improvement: 0.0035088766597085397
# - Actual improvement: 0.0018472018620698805
# - (z = 0.5264368175948698)
#
# *** Iteration: 55 ***
# New cost: 58.711522448216556
# - Expected improvement: 0.0011626887458160873
# - Actual improvement: 0.0006105531853179968
# - (z = 0.5251217813151289)
#
# *** Iteration: 56 ***
# New cost: 58.71132209384236
# - Expected improvement: 0.000382086826416845
# - Actual improvement: 0.0002003543741935232
# - (z = 0.5243687045492187)
#
# *** Iteration: 57 ***
# New cost: 58.71125661787858
# - Expected improvement: 0.0001249688522084687
# - Actual improvement: 6.547596377970422e-5
# - (z = 0.5239382663968096)
#
# *** Iteration: 58 ***
# New cost: 58.71123527065698
# - Expected improvement: 4.076289271652387e-5
# - Actual improvement: 2.134722160462843e-5
# - (z = 0.5236925100748554)
#
# *** Iteration: 59 ***
# New cost: 58.711228320147264
# - Expected improvement: 1.3275674481756783e-5
# - Actual improvement: 6.950509714442887e-6
# - (z = 0.5235522853467193)
#
# -----SOLVED-----
# eps criteria met at iteration: 59

# %%
P = plot(linspace(0,tf,size(X,2)),X[1,:])
P = plot!(linspace(0,tf,size(X,2)),X[2,:])

# %%
W = plot(linspace(0,tf,size(X,2)),[U[1,:]; U[1,end]],title="Pendulum",ylabel="Control")

# %%
plt = plot()
@gif for i=1:size(X,2)
    x = cos(X[1,i] - pi/2)
    y = sin(X[1,i] - pi/2)
    plt = plot([0,x],[0,y],xlims=(-1.5,1.5),ylims=(-1.5,1.5),color="black",size=(200,200),label="",title="Pendulum")
end
# Out:
# INFO: Saved animation to C:\Users\taylor howell\Google Drive\Stanford\Research-Manchester\iLQR demos\tmp.gif
# Plots.AnimatedGif("C:\\Users\\taylor howell\\Google Drive\\Stanford\\Research-Manchester\\iLQR demos\\tmp.gif")
