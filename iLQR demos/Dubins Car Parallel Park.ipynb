# %%
using ForwardDiff
using Plots

# %%
# Dubins car parallel park

n = 3 # number of states
m = 2 # number of controls

# initial and goal states
x0 = [0.;0.;0.]
xf = [0.;1.;0.]

# costs
Q = 0.001*eye(n)
Qf = 100.0*eye(n)
R = 0.001*eye(m)

# simulation
tf = 5.0
dt = 0.01
# Out:
# 0.01

# %%
# Dynamics (RK4 discretization)
function fc(x,u)
    return [u[1]*cos(x[3]); u[1]*sin(x[3]); u[2]]
end

function f(x,u,dt)
    # Runge-Kutta 4
    k1 = dt*fc(x,u)
    k2 = dt*fc(x + k1/2,u)
    k3 = dt*fc(x + k2/2,u)
    k4 = dt*fc(x + k3, u)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

function fc_aug(S)
    return [S[4]*cos(S[3]); S[4]*sin(S[3]); S[5]; 0.0; 0.0; 0.0] 
    
end

function f_aug(S)
    k1 = S[end]*fc_aug(S)
    k2 = S[end]*fc_aug(S + k1/2)
    k3 = S[end]*fc_aug(S + k2/2)
    k4 = S[end]*fc_aug(S + k3)
    return S + (k1 + 2*k2 + 2*k3 + k4)/6
end

F = S-> ForwardDiff.jacobian(f_aug, S)
# Out:
# (::#149) (generic function with 1 method)

# %%
#iLQR
function rollout(x0,U,f,dt,tf)
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    X[:,1] = x0
    for k = 1:N-1
      X[:,k+1] = f(X[:,k],U[:,k],dt)
    end
    return X
end

function cost(X,U,Q,R,Qf,xf)
    N = size(X,2)
    J = 0.0
    for k = 1:N-1
      J += 0.5*(X[:,k] - xf)'*Q*(X[:,k] - xf) + 0.5*U[:,k]'*R*U[:,k]
    end
    J += 0.5*(X[:,N] - xf)'*Qf*(X[:,N] - xf)
    return J
end

function backwardpass(X,U,F,Q,R,Qf,xf)
    n, N = size(X)
    m = size(U,1)
    
    S = zeros(n,n,N)
    s = zeros(n,N)
    
    Qx = zeros(n,1,N)
    Qu = zeros(m,1,N)
    Qxx = zeros(n,n,N)
    Quu = zeros(m,m,N)
    Qux = zeros(m,n,N)
    
    K = zeros(m,n,N-1)
    l = zeros(m,N-1)
    
    S[:,:,N] = Qf
    s[:,N] = Qf*(X[:,N] - xf)
    v1 = 0.0
    v2 = 0.0

    mu = 0.0
    k = N-1
    
    while k >= 1
        q = Q*(X[:,k] - xf)
        r = R*(U[:,k])
        F_aug = F([X[:,k];U[:,k];dt])
        fx = F_aug[1:size(X,1),1:size(X,1)]
        fu = F_aug[1:size(X,1),size(X,1)+1:size(X,1)+size(U,1)]
        
        Qx[:,:,k] = q + fx'*s[:,k+1]
        Qu[:,:,k] = r + fu'*s[:,k+1]
        Qxx[:,:,k] = Q + fx'*S[:,:,k+1]*fx
        Quu[:,:,k] = R + fu'*(S[:,:,k+1] + mu*eye(n))*fu
        Qux[:,:,k] = fu'*(S[:,:,k+1] + mu*eye(n))*fx

        # regularization        
        if any(x->x < 0.0, (eigvals(Quu[:,:,k])))
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end
        
        K[:,:,k] = Quu[:,:,k]\Qux[:,:,k]
        l[:,k] = Quu[:,:,k]\Qu[:,:,k]
        s[:,k] = (Qx[:,:,k]' - Qu[:,:,k]'*K[:,:,k] + l[:,k]'*Quu[:,:,k]*K[:,:,k] - l[:,k]'*Qux[:,:,k])'
        S[:,:,k] = Qxx[:,:,k] + K[:,:,k]'*Quu[:,:,k]*K[:,:,k] - K[:,:,k]'*Qux[:,:,k] - Qux[:,:,k]'*K[:,:,k]

        # terms for line search
        v1 += l[:,k]'*Qu[:,:,k]
        v2 += l[:,k]'*Quu[:,:,k]*l[:,k]
        
        k = k - 1;
    end
    return K, l, v1, v2
end

function forwardpass(X,U,f,J,K,l,v1,v2,c1=0.0,c2=1.0)
    N = size(X,2)
    m = size(U,1)
    X_prev = copy(X)
    J_prev = copy(J)
    U_ = zeros(m,N-1)
    J = Inf
    dV = 0.0
    dJ = 0.0
    z = 0.0
    
    alpha = 1.0

    while J > J_prev || z < c1 || z > c2 
        for k = 1:N-1
          U_[:,k] = U[:,k] - K[:,:,k]*(X[:,k] - X_prev[:,k]) - alpha*l[:,k]
          X[:,k+1] = f(X[:,k],U_[:,k],dt);
        end

        J = cost(X,U_,Q,R,Qf,xf)
        
        dV = alpha*v1 + (alpha^2)*v2/2.0
        dJ = J_prev - J
        z = dJ/dV[1]

        alpha = alpha/2.0;
    end

    println("New cost: $J")
    println("- Expected improvement: $(dV[1])")
    println("- Actual improvement: $(dJ)")
    println("- (z = $z)\n")
    
    return X, U_, J
end

function solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,iterations=100,eps=1e-5;control_init="random")
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    
    if control_init == "random"
        U = 10.0*rand(m,N-1)
    else
        U = zeros(m,N-1)
    end
        
    X = rollout(x0,U,f,dt,tf)
    J_prev = cost(X,U,Q,R,Qf,xf)
    println("Initial Cost: $J_prev\n")
    
    for i = 1:iterations
        println("*** Iteration: $i ***")
        K, l, v1, v2 = backwardpass(X,U,F,Q,R,Qf,xf)
        X, U, J = forwardpass(X,U,f,J_prev,K,l,v1,v2)

        if abs(J-J_prev) < eps
          println("-----SOLVED-----")
          println("eps criteria met at iteration: $i")
          break
        end
        J_prev = copy(J)
    end
    
    return X, U
end
# Out:
# solve (generic function with 4 methods)

# %%
X, U = @time solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,control_init="random");
# Out:
# Initial Cost: 33369.19933504121
#
# *** Iteration: 1 ***
# New cost: 6524.06771183919
# - Expected improvement: 99923.60093067298
# - Actual improvement: 26845.131623202018
# - (z = 0.2686565673491608)
#
# *** Iteration: 2 ***
# New cost: 1539.9357658295035
# - Expected improvement: 18627.488204091598
# - Actual improvement: 4984.131946009687
# - (z = 0.26756865399141166)
#
# *** Iteration: 3 ***
# New cost: 1090.8316056660283
# - Expected improvement: 1764.1826572239238
# - Actual improvement: 449.10416016347517
# - (z = 0.2545678353227748)
#
# *** Iteration: 4 ***
# New cost: 292.768619559848
# - Expected improvement: 3040.7000655547045
# - Actual improvement: 798.0629861061802
# - (z = 0.26246027852161485)
#
# *** Iteration: 5 ***
# New cost: 235.97243171030772
# - Expected improvement: 70.0426977040336
# - Actual improvement: 56.796187849540274
# - (z = 0.8108795022363839)
#
# *** Iteration: 6 ***
# New cost: 171.57265829513383
# - Expected improvement: 119.79346176461854
# - Actual improvement: 64.39977341517388
# - (z = 0.5375900526333617)
#
# *** Iteration: 7 ***
# New cost: 136.81948017851244
# - Expected improvement: 176.54025098283736
# - Actual improvement: 34.7531781166214
# - (z = 0.19685696561063565)
#
# *** Iteration: 8 ***
# New cost: 129.24057400032706
# - Expected improvement: 62.63579601877624
# - Actual improvement: 7.5789061781853775
# - (z = 0.12099959863068492)
#
# *** Iteration: 9 ***
# New cost: 112.7525572429595
# - Expected improvement: 28.12898738504275
# - Actual improvement: 16.48801675736756
# - (z = 0.586157494106413)
#
# *** Iteration: 10 ***
# New cost: 91.4143802272826
# - Expected improvement: 27.037985739465935
# - Actual improvement: 21.33817701567689
# - (z = 0.789192553812567)
#
# *** Iteration: 11 ***
# New cost: 66.59231064313867
# - Expected improvement: 48.17929884461049
# - Actual improvement: 24.822069584143932
# - (z = 0.5152019680527297)
#
# *** Iteration: 12 ***
# New cost: 30.04167716818513
# - Expected improvement: 79.69152744727663
# - Actual improvement: 36.55063347495354
# - (z = 0.4586514356765867)
#
# *** Iteration: 13 ***
# New cost: 14.506263316219336
# - Expected improvement: 34.32547269589202
# - Actual improvement: 15.535413851965796
# - (z = 0.45259140317170443)
#
# *** Iteration: 14 ***
# New cost: 12.770174512535153
# - Expected improvement: 15.776400958949461
# - Actual improvement: 1.7360888036841828
# - (z = 0.11004340015200702)
#
# *** Iteration: 15 ***
# New cost: 2.4763446759016863
# - Expected improvement: 15.57404141943019
# - Actual improvement: 10.293829836633467
# - (z = 0.6609607332744649)
#
# *** Iteration: 16 ***
# New cost: 1.561030162699858
# - Expected improvement: 6.230795925218597
# - Actual improvement: 0.9153145132018283
# - (z = 0.14690169990918392)
#
# *** Iteration: 17 ***
# New cost: 0.3453871065357649
# - Expected improvement: 3.6364481245033486
# - Actual improvement: 1.215643056164093
# - (z = 0.334294073376922)
#
# *** Iteration: 18 ***
# New cost: 0.3278394926299648
# - Expected improvement: 0.051065756830378436
# - Actual improvement: 0.017547613905800064
# - (z = 0.34362780452048813)
#
# *** Iteration: 19 ***
# New cost: 0.3218003801623774
# - Expected improvement: 0.0242150763664867
# - Actual improvement: 0.006039112467587426
# - (z = 0.24939473145521301)
#
# *** Iteration: 20 ***
# New cost: 0.31891761345478553
# - Expected improvement: 0.017847428675470123
# - Actual improvement: 0.002882766707591855
# - (z = 0.16152280308893963)
#
# *** Iteration: 21 ***
# New cost: 0.3174859916361327
# - Expected improvement: 0.013861563839526605
# - Actual improvement: 0.0014316218186528062
# - (z = 0.1032799643118549)
#
# *** Iteration: 22 ***
# New cost: 0.31665130503645683
# - Expected improvement: 0.011780414674783843
# - Actual improvement: 0.0008346865996758934
# - (z = 0.07085375368513579)
#
# *** Iteration: 23 ***
# New cost: 0.31619164615489453
# - Expected improvement: 0.010053864029899969
# - Actual improvement: 0.00045965888156229706
# - (z = 0.04571962383768884)
#
# *** Iteration: 24 ***
# New cost: 0.31583024519591607
# - Expected improvement: 0.00897808382309031
# - Actual improvement: 0.0003614009589784639
# - (z = 0.040253685095810066)
#
# *** Iteration: 25 ***
# New cost: 0.31561042494603675
# - Expected improvement: 0.007880119810453525
# - Actual improvement: 0.00021982024987932114
# - (z = 0.027895546662591898)
#
# *** Iteration: 26 ***
# New cost: 0.31539047879140936
# - Expected improvement: 0.00713366227782317
# - Actual improvement: 0.00021994615462739286
# - (z = 0.030832151293614257)
#
# *** Iteration: 27 ***
# New cost: 0.31524348182619694
# - Expected improvement: 0.0063308280644638545
# - Actual improvement: 0.00014699696521242034
# - (z = 0.023219231941796422)
#
# *** Iteration: 28 ***
# New cost: 0.3150790730340071
# - Expected improvement: 0.005759776147727584
# - Actual improvement: 0.00016440879218981852
# - (z = 0.02854430241263509)
#
# *** Iteration: 29 ***
# New cost: 0.3149592808915007
# - Expected improvement: 0.005148088927910709
# - Actual improvement: 0.00011979214250640302
# - (z = 0.0232692449924363)
#
# *** Iteration: 30 ***
# New cost: 0.3148218027599383
# - Expected improvement: 0.004699400238014321
# - Actual improvement: 0.0001374781315623963
# - (z = 0.02925439941256975)
#
# *** Iteration: 31 ***
# New cost: 0.31471333449775996
# - Expected improvement: 0.0042278370086135195
# - Actual improvement: 0.0001084682621783628
# - (z = 0.025655734115902915)
#
# *** Iteration: 32 ***
# New cost: 0.31458968034238716
# - Expected improvement: 0.0038731709168223593
# - Actual improvement: 0.00012365415537279878
# - (z = 0.03192581944569788)
#
# *** Iteration: 33 ***
# New cost: 0.3144848042258273
# - Expected improvement: 0.0035083265886467034
# - Actual improvement: 0.00010487611655984885
# - (z = 0.029893487367806202)
#
# *** Iteration: 34 ***
# New cost: 0.3143668859125545
# - Expected improvement: 0.003227951379576585
# - Actual improvement: 0.00011791831327279123
# - (z = 0.03653038704946626)
#
# *** Iteration: 35 ***
# New cost: 0.31426039513192244
# - Expected improvement: 0.002945374423622654
# - Actual improvement: 0.00010649078063207362
# - (z = 0.03615526086530473)
#
# *** Iteration: 36 ***
# New cost: 0.31414214473988333
# - Expected improvement: 0.0027241056701057314
# - Actual improvement: 0.00011825039203910981
# - (z = 0.043408885836106394)
#
# *** Iteration: 37 ***
# New cost: 0.31402974727846905
# - Expected improvement: 0.0025052779334828927
# - Actual improvement: 0.00011239746141428197
# - (z = 0.04486426831614029)
#
# *** Iteration: 38 ***
# New cost: 0.31390610663155266
# - Expected improvement: 0.0023310810599873125
# - Actual improvement: 0.00012364064691638976
# - (z = 0.053040046113652824)
#
# *** Iteration: 39 ***
# New cost: 0.3137839203376906
# - Expected improvement: 0.002161822604590831
# - Actual improvement: 0.00012218629386206992
# - (z = 0.05652003712173052)
#
# *** Iteration: 40 ***
# New cost: 0.3136504409459637
# - Expected improvement: 0.0020250791181509356
# - Actual improvement: 0.00013347939172686507
# - (z = 0.06591317372762343)
#
# *** Iteration: 41 ***
# New cost: 0.3135148381769263
# - Expected improvement: 0.0018944609487169042
# - Actual improvement: 0.00013560276903740176
# - (z = 0.07157855068442762)
#
# *** Iteration: 42 ***
# New cost: 0.3133675212509455
# - Expected improvement: 0.0017874480688103633
# - Actual improvement: 0.00014731692598080048
# - (z = 0.08241745791185269)
#
# *** Iteration: 43 ***
# New cost: 0.3132151195327858
# - Expected improvement: 0.0016869782894140804
# - Actual improvement: 0.0001524017181597226
# - (z = 0.09034005897767339)
#
# *** Iteration: 44 ***
# New cost: 0.31305038997438256
# - Expected improvement: 0.0016034532797315427
# - Actual improvement: 0.00016472955840324266
# - (z = 0.10273424270323761)
#
# *** Iteration: 45 ***
# New cost: 0.31287813395016334
# - Expected improvement: 0.001526451312295428
# - Actual improvement: 0.00017225602421921948
# - (z = 0.11284737536776489)
#
# *** Iteration: 46 ***
# New cost: 0.31269291483792455
# - Expected improvement: 0.001461309495117217
# - Actual improvement: 0.00018521911223878806
# - (z = 0.12674872288018013)
#
# *** Iteration: 47 ***
# New cost: 0.3124982338091767
# - Expected improvement: 0.001402422475216892
# - Actual improvement: 0.0001946810287478673
# - (z = 0.13881767597724706)
#
# *** Iteration: 48 ***
# New cost: 0.312290105377316
# - Expected improvement: 0.0013514179130858666
# - Actual improvement: 0.00020812843186068797
# - (z = 0.1540074538345)
#
# *** Iteration: 49 ***
# New cost: 0.3120711354430896
# - Expected improvement: 0.0013062507266538115
# - Actual improvement: 0.00021896993422637623
# - (z = 0.16763239227993068)
#
# *** Iteration: 50 ***
# New cost: 0.31183856007305155
# - Expected improvement: 0.0012657764065537535
# - Actual improvement: 0.00023257537003806839
# - (z = 0.18374127439401886)
#
# *** Iteration: 51 ***
# New cost: 0.31159441051848485
# - Expected improvement: 0.001230618974043177
# - Actual improvement: 0.0002441495545666972
# - (z = 0.19839573394886648)
#
# *** Iteration: 52 ***
# New cost: 0.311336992915072
# - Expected improvement: 0.0011975480815822667
# - Actual improvement: 0.00025741760341285724
# - (z = 0.21495387731968382)
#
# *** Iteration: 53 ***
# New cost: 0.3110680201434903
# - Expected improvement: 0.001169192316238128
# - Actual improvement: 0.0002689727715817214
# - (z = 0.23005006776570366)
#
# *** Iteration: 54 ***
# New cost: 0.31078675501265884
# - Expected improvement: 0.0011407841909096602
# - Actual improvement: 0.0002812651308314318
# - (z = 0.2465541976060794)
#
# *** Iteration: 55 ***
# New cost: 0.3104947897175886
# - Expected improvement: 0.0011164270591041065
# - Actual improvement: 0.00029196529507025115
# - (z = 0.26151757312702817)
#
# *** Iteration: 56 ***
# New cost: 0.31019223448815575
# - Expected improvement: 0.0010902989675530992
# - Actual improvement: 0.00030255522943284374
# - (z = 0.2774974923729888)
#
# *** Iteration: 57 ***
# New cost: 0.3098806966888441
# - Expected improvement: 0.0010675253878169911
# - Actual improvement: 0.00031153779931164527
# - (z = 0.29183174739170986)
#
# *** Iteration: 58 ***
# New cost: 0.3095610027794264
# - Expected improvement: 0.0010416830859726876
# - Actual improvement: 0.0003196939094177176
# - (z = 0.3069013154986562)
#
# *** Iteration: 59 ***
# New cost: 0.30923484368716436
# - Expected improvement: 0.0010185127080441319
# - Actual improvement: 0.0003261590922620239
# - (z = 0.32023075380998733)
#
# *** Iteration: 60 ***
# New cost: 0.30890359465272715
# - Expected improvement: 0.0009914200272829543
# - Actual improvement: 0.00033124903443720877
# - (z = 0.3341157383566443)
#
# *** Iteration: 61 ***
# New cost: 0.30856903013583714
# - Expected improvement: 0.0009663882649397191
# - Actual improvement: 0.00033456451689001243
# - (z = 0.34620093085555187)
#
# *** Iteration: 62 ***
# New cost: 0.3082328714401519
# - Expected improvement: 0.0009370432979294822
# - Actual improvement: 0.00033615869568526247
# - (z = 0.3587440371518033)
#
# *** Iteration: 63 ***
# New cost: 0.3078969171522953
# - Expected improvement: 0.0009092760476619303
# - Actual improvement: 0.0003359542878565991
# - (z = 0.3694744722688519)
#
# *** Iteration: 64 ***
# New cost: 0.3075630131989629
# - Expected improvement: 0.000877255953637359
# - Actual improvement: 0.00033390395333238176
# - (z = 0.38062318294668573)
#
# *** Iteration: 65 ***
# New cost: 0.3072328837432926
# - Expected improvement: 0.0008464970097082493
# - Actual improvement: 0.0003301294556702916
# - (z = 0.38999482796055346)
#
# *** Iteration: 66 ***
# New cost: 0.30690828648966223
# - Expected improvement: 0.0008119406078339479
# - Actual improvement: 0.0003245972536303765
# - (z = 0.39977955345320126)
#
# *** Iteration: 67 ***
# New cost: 0.30659076094965404
# - Expected improvement: 0.0007785048834580675
# - Actual improvement: 0.00031752554000819
# - (z = 0.40786582943161825)
#
# *** Iteration: 68 ***
# New cost: 0.3062818015515948
# - Expected improvement: 0.0007420218034065434
# - Actual improvement: 0.00030895939805924977
# - (z = 0.41637509388652727)
#
# *** Iteration: 69 ***
# New cost: 0.30598266850498257
# - Expected improvement: 0.0007066724540574888
# - Actual improvement: 0.00029913304661222107
# - (z = 0.4232980143695911)
#
# *** Iteration: 70 ***
# New cost: 0.3056944772734869
# - Expected improvement: 0.0006691922606288439
# - Actual improvement: 0.0002881912314956492
# - (z = 0.4306553563916507)
#
# *** Iteration: 71 ***
# New cost: 0.30541814928501426
# - Expected improvement: 0.0006329653839077392
# - Actual improvement: 0.0002763279884726577
# - (z = 0.4365609802651312)
#
# *** Iteration: 72 ***
# New cost: 0.30515437257971756
# - Expected improvement: 0.0005955590322108007
# - Actual improvement: 0.0002637767052967033
# - (z = 0.44290606141514843)
#
# *** Iteration: 73 ***
# New cost: 0.3049037132863073
# - Expected improvement: 0.0005595747852411568
# - Actual improvement: 0.0002506592934102825
# - (z = 0.4479460119030511)
#
# *** Iteration: 74 ***
# New cost: 0.30466644441586394
# - Expected improvement: 0.0005232863579152778
# - Actual improvement: 0.00023726887044334122
# - (z = 0.45342070714130106)
#
# *** Iteration: 75 ***
# New cost: 0.30444279964482635
# - Expected improvement: 0.0004885849400777243
# - Actual improvement: 0.00022364477103758995
# - (z = 0.45773979648658925)
#
# *** Iteration: 76 ***
# New cost: 0.3042326938295482
# - Expected improvement: 0.00045430351146600624
# - Actual improvement: 0.00021010581527813876
# - (z = 0.46247895949591433)
#
# *** Iteration: 77 ***
# New cost: 0.30403607926441184
# - Expected improvement: 0.0004217314276904237
# - Actual improvement: 0.000196614565136366
# - (z = 0.4662079992783771)
#
# *** Iteration: 78 ***
# New cost: 0.30385259392879516
# - Expected improvement: 0.0003901170408700856
# - Actual improvement: 0.00018348533561668434
# - (z = 0.470334070020252)
#
# *** Iteration: 79 ***
# New cost: 0.3036819742920521
# - Expected improvement: 0.00036027125999859227
# - Actual improvement: 0.00017061963674303016
# - (z = 0.47358658790517133)
#
# *** Iteration: 80 ***
# New cost: 0.30352366889032123
# - Expected improvement: 0.0003317331456544482
# - Actual improvement: 0.00015830540173089602
# - (z = 0.47720706780321487)
#
# *** Iteration: 81 ***
# New cost: 0.30337726610070775
# - Expected improvement: 0.00030495582700109704
# - Actual improvement: 0.00014640278961347564
# - (z = 0.4800786758304801)
#
# *** Iteration: 82 ***
# New cost: 0.3032421053937038
# - Expected improvement: 0.0002796704790768623
# - Actual improvement: 0.00013516070700397842
# - (z = 0.4832855703974104)
#
# *** Iteration: 83 ***
# New cost: 0.3031176882389685
# - Expected improvement: 0.00025607880718130484
# - Actual improvement: 0.00012441715473526793
# - (z = 0.4858549448302455)
#
# *** Iteration: 84 ***
# New cost: 0.30300331095688643
# - Expected improvement: 0.00023403177421256677
# - Actual improvement: 0.00011437728208207876
# - (z = 0.48872544109413096)
#
# *** Iteration: 85 ***
# New cost: 0.30289843802446065
# - Expected improvement: 0.0002135660729363444
# - Actual improvement: 0.00010487293242578133
# - (z = 0.4910561447512302)
#
# *** Iteration: 86 ***
# New cost: 0.30280237157830747
# - Expected improvement: 0.00019460280001208093
# - Actual improvement: 9.606644615317572e-5
# - (z = 0.4936539769582551)
#
# *** Iteration: 87 ***
# New cost: 0.30271457633792964
# - Expected improvement: 0.0001770791475701943
# - Actual improvement: 8.779524037783037e-5
# - (z = 0.49579660610817133)
#
# *** Iteration: 88 ***
# New cost: 0.3026343931222602
# - Expected improvement: 0.00016095432356984498
# - Actual improvement: 8.01832156694382e-5
# - (z = 0.49817372960871886)
#
# *** Iteration: 89 ***
# New cost: 0.3025613122440466
# - Expected improvement: 0.00014611264283658225
# - Actual improvement: 7.308087821361609e-5
# - (z = 0.5001680675597143)
#
# *** Iteration: 90 ***
# New cost: 0.30249473259340437
# - Expected improvement: 0.0001325320549798027
# - Actual improvement: 6.657965064221782e-5
# - (z = 0.5023663946987336)
#
# *** Iteration: 91 ***
# New cost: 0.3024341854879712
# - Expected improvement: 0.00012007515764650724
# - Actual improvement: 6.054710543318409e-5
# - (z = 0.5042433973847487)
#
# *** Iteration: 92 ***
# New cost: 0.3023791370126757
# - Expected improvement: 0.00010872775323282903
# - Actual improvement: 5.504847529547163e-5
# - (z = 0.5062964483188678)
#
# *** Iteration: 93 ***
# New cost: 0.3023291672727592
# - Expected improvement: 9.835014492783906e-5
# - Actual improvement: 4.99697399165e-5
# - (z = 0.5080799825273621)
#
# *** Iteration: 94 ***
# New cost: 0.3022838114740476
# - Expected improvement: 8.89304323024138e-5
# - Actual improvement: 4.535579871162154e-5
# - (z = 0.5100143734530173)
#
# *** Iteration: 95 ***
# New cost: 0.30224270085736
# - Expected improvement: 8.033768642404347e-5
# - Actual improvement: 4.111061668760074e-5
# - (z = 0.511722686045601)
#
# *** Iteration: 96 ***
# New cost: 0.30220543704401276
# - Expected improvement: 7.255988629955844e-5
# - Actual improvement: 3.72638133472325e-5
# - (z = 0.5135594230866273)
#
# *** Iteration: 97 ***
# New cost: 0.302171701168271
# - Expected improvement: 6.548031787124818e-5
# - Actual improvement: 3.373587574173609e-5
# - (z = 0.5152063526641676)
#
# *** Iteration: 98 ***
# New cost: 0.30214115589059004
# - Expected improvement: 5.90861261323609e-5
# - Actual improvement: 3.054527768098225e-5
# - (z = 0.5169619279584636)
#
# *** Iteration: 99 ***
# New cost: 0.30211352883317116
# - Expected improvement: 5.3276708690142035e-5
# - Actual improvement: 2.76270574188775e-5
# - (z = 0.5185578857649933)
#
# *** Iteration: 100 ***
# New cost: 0.3020885370411628
# - Expected improvement: 4.803848755603857e-5
# - Actual improvement: 2.4991792008377534e-5
# - (z = 0.520245188386161)
#
#  11.750498 seconds (21.08 M allocations: 1.824 GiB, 20.05% gc time)

# %%
plot((x0[1],x0[2]),marker=(:circle,"red"),label="x0")
plot!((xf[1],xf[2]),marker=(:circle,"green"),label="xf")
plot!(X[1,:],X[2,:],title="Dubins Car Parallel Park",label="traj.",color="blue",xlim=(-2,2),ylim=(-2,2))

# %%
W = plot(linspace(0,tf,size(X,2)),[U[1,1] U[1,:]']',title="Dubins Car Parallel Park",label="u1")
W = plot!(linspace(0,tf,size(X,2)),[U[2,1] U[2,:]']',ylabel="Control",label="u2")
