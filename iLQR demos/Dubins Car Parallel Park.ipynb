# %%
using ForwardDiff
using Plots

# %%
# Dubins car parallel park

n = 3 # number of states
m = 2 # number of controls

# initial and goal states
x0 = [0.;0.;0.]
xf = [0.;1.;0.]

# costs
Q = 0.001*eye(n)
Qf = 100.0*eye(n)
R = 0.001*eye(m)

# simulation
tf = 5.0
dt = 0.01
# Out:
# 0.01

# %%
# Dynamics (RK4 discretization)
function fc(x,u)
    return [u[1]*cos(x[3]); u[1]*sin(x[3]); u[2]]
end

function f(x,u,dt)
    # Runge-Kutta 4
    k1 = dt*fc(x,u)
    k2 = dt*fc(x + k1/2,u)
    k3 = dt*fc(x + k2/2,u)
    k4 = dt*fc(x + k3, u)
    return x + (k1 + 2*k2 + 2*k3 + k4)/6
end

function fc_aug(S)
    return [S[4]*cos(S[3]); S[4]*sin(S[3]); S[5]; 0.0; 0.0; 0.0] 
    
end

function f_aug(S)
    k1 = S[end]*fc_aug(S)
    k2 = S[end]*fc_aug(S + k1/2)
    k3 = S[end]*fc_aug(S + k2/2)
    k4 = S[end]*fc_aug(S + k3)
    return S + (k1 + 2*k2 + 2*k3 + k4)/6
end

F = S-> ForwardDiff.jacobian(f_aug, S)
# Out:
# (::#129) (generic function with 1 method)

# %%
#iLQR
function rollout(x0,U,f,dt,tf)
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    X[:,1] = x0
    for k = 1:N-1
      X[:,k+1] = f(X[:,k],U[:,k],dt)
    end
    return X
end

function cost(X,U,Q,R,Qf,xf)
    N = size(X,2)
    J = 0.0
    for k = 1:N-1
      J += 0.5*(X[:,k] - xf)'*Q*(X[:,k] - xf) + 0.5*U[:,k]'*R*U[:,k]
    end
    J += 0.5*(X[:,N] - xf)'*Qf*(X[:,N] - xf)
    return J
end

function backwardpass(X,U,F,Q,R,Qf,xf)
    n, N = size(X)
    m = size(U,1)
    
    S = zeros(n,n,N)
    s = zeros(n,N)
    
    Qx = zeros(n,1,N)
    Qu = zeros(m,1,N)
    Qxx = zeros(n,n,N)
    Quu = zeros(m,m,N)
    Qux = zeros(m,n,N)
    
    K = zeros(m,n,N-1)
    l = zeros(m,N-1)
    
    S[:,:,N] = Qf
    s[:,N] = Qf*(X[:,N] - xf)
    v1 = 0.0
    v2 = 0.0

    mu = 0.0
    k = N-1
    
    while k >= 1
        q = Q*(X[:,k] - xf)
        r = R*(U[:,k])
        F_aug = F([X[:,k];U[:,k];dt])
        fx = F_aug[1:size(X,1),1:size(X,1)]
        fu = F_aug[1:size(X,1),size(X,1)+1:size(X,1)+size(U,1)]
        
        Qx[:,:,k] = q + fx'*s[:,k+1]
        Qu[:,:,k] = r + fu'*s[:,k+1]
        Qxx[:,:,k] = Q + fx'*S[:,:,k+1]*fx
        Quu[:,:,k] = R + fu'*(S[:,:,k+1] + mu*eye(n))*fu
        Qux[:,:,k] = fu'*(S[:,:,k+1] + mu*eye(n))*fx

        # regularization        
        if any(x->x < 0.0, (eigvals(Quu[:,:,k])))
            mu = mu + 1.0;
            k = N-1;
            println("regularized")
        end
        
        K[:,:,k] = Quu[:,:,k]\Qux[:,:,k]
        l[:,k] = Quu[:,:,k]\Qu[:,:,k]
        s[:,k] = (Qx[:,:,k]' - Qu[:,:,k]'*K[:,:,k] + l[:,k]'*Quu[:,:,k]*K[:,:,k] - l[:,k]'*Qux[:,:,k])'
        S[:,:,k] = Qxx[:,:,k] + K[:,:,k]'*Quu[:,:,k]*K[:,:,k] - K[:,:,k]'*Qux[:,:,k] - Qux[:,:,k]'*K[:,:,k]

        # terms for line search
        v1 += l[:,k]'*Qu[:,:,k]
        v2 += l[:,k]'*Quu[:,:,k]*l[:,k]
        
        k = k - 1;
    end
    return K, l, v1, v2
end

function forwardpass(X,U,f,J,K,l,v1,v2,c1=0.0,c2=1.0)
    N = size(X,2)
    m = size(U,1)
    X_prev = copy(X)
    J_prev = copy(J)
    U_ = zeros(m,N-1)
    J = Inf
    dV = 0.0
    dJ = 0.0
    z = 0.0
    
    alpha = 1.0

    while J > J_prev || z < c1 || z > c2 
        for k = 1:N-1
          U_[:,k] = U[:,k] - K[:,:,k]*(X[:,k] - X_prev[:,k]) - alpha*l[:,k]
          X[:,k+1] = f(X[:,k],U_[:,k],dt);
        end

        J = cost(X,U_,Q,R,Qf,xf)
        
        dV = alpha*v1 + (alpha^2)*v2/2.0
        dJ = J_prev - J
        z = dJ/dV[1]

        alpha = alpha/2.0;
    end

    println("New cost: $J")
    println("- Expected improvement: $(dV[1])")
    println("- Actual improvement: $(dJ)")
    println("- (z = $z)\n")
    
    return X, U_, J
end

function solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,iterations=100,eps=1e-5;control_init="random")
    N = convert(Int64,floor(tf/dt))
    X = zeros(size(x0,1),N)
    
    if control_init == "random"
        U = 10.0*rand(m,N-1)
    else
        U = zeros(m,N-1)
    end
        
    X = rollout(x0,U,f,dt,tf)
    J_prev = cost(X,U,Q,R,Qf,xf)
    println("Initial Cost: $J_prev\n")
    
    for i = 1:iterations
        println("*** Iteration: $i ***")
        K, l, v1, v2 = backwardpass(X,U,F,Q,R,Qf,xf)
        X, U, J = forwardpass(X,U,f,J_prev,K,l,v1,v2)

        if abs(J-J_prev) < eps
          println("-----SOLVED-----")
          println("eps criteria met at iteration: $i")
          break
        end
        J_prev = copy(J)
    end
    
    return X, U
end
# Out:
# solve (generic function with 4 methods)

# %%
X, U = @time solve(x0,m,f,F,Q,R,Qf,xf,dt,tf,control_init="random");
# Out:
# Initial Cost: 32329.153496473937
#
# *** Iteration: 1 ***
# New cost: 17731.28302919725
# - Expected improvement: 40315.59768876474
# - Actual improvement: 14597.870467276687
# - (z = 0.362089893345296)
#
# *** Iteration: 2 ***
# New cost: 7462.700897468295
# - Expected improvement: 51578.40233317029
# - Actual improvement: 10268.582131728956
# - (z = 0.19908685936797982)
#
# *** Iteration: 3 ***
# New cost: 5340.166839868586
# - Expected improvement: 4155.639166525678
# - Actual improvement: 2122.534057599709
# - (z = 0.5107599511278679)
#
# *** Iteration: 4 ***
# New cost: 4413.350257998336
# - Expected improvement: 15884.78498909278
# - Actual improvement: 926.81658187025
# - (z = 0.05834618362833647)
#
# *** Iteration: 5 ***
# New cost: 1354.0944931246731
# - Expected improvement: 12543.245438487498
# - Actual improvement: 3059.255764873663
# - (z = 0.24389666772258878)
#
# *** Iteration: 6 ***
# New cost: 730.8448991264895
# - Expected improvement: 4046.9000428447107
# - Actual improvement: 623.2495939981836
# - (z = 0.1540066686599156)
#
# *** Iteration: 7 ***
# New cost: 579.1042228667986
# - Expected improvement: 191.40771445196864
# - Actual improvement: 151.74067625969087
# - (z = 0.7927615493145042)
#
# *** Iteration: 8 ***
# New cost: 519.2116475363205
# - Expected improvement: 323.6284413420585
# - Actual improvement: 59.89257533047817
# - (z = 0.1850658584953441)
#
# *** Iteration: 9 ***
# New cost: 193.48314688580373
# - Expected improvement: 643.9021282494848
# - Actual improvement: 325.7285006505167
# - (z = 0.5058664762237138)
#
# *** Iteration: 10 ***
# New cost: 141.39507653785168
# - Expected improvement: 579.5497701310181
# - Actual improvement: 52.088070347952055
# - (z = 0.0898767854504999)
#
# *** Iteration: 11 ***
# New cost: 36.890317478376645
# - Expected improvement: 422.64779159901235
# - Actual improvement: 104.50475905947503
# - (z = 0.2472620492445967)
#
# *** Iteration: 12 ***
# New cost: 8.125772644297044
# - Expected improvement: 109.89468315531697
# - Actual improvement: 28.7645448340796
# - (z = 0.26174646496251264)
#
# *** Iteration: 13 ***
# New cost: 0.6989923952933516
# - Expected improvement: 23.45706961463349
# - Actual improvement: 7.426780249003692
# - (z = 0.3166115960354468)
#
# *** Iteration: 14 ***
# New cost: 0.43908562988957417
# - Expected improvement: 0.5280060299601559
# - Actual improvement: 0.2599067654037774
# - (z = 0.4922420401588791)
#
# *** Iteration: 15 ***
# New cost: 0.3485844952631126
# - Expected improvement: 0.38741917134367176
# - Actual improvement: 0.09050113462646159
# - (z = 0.23360004181667057)
#
# *** Iteration: 16 ***
# New cost: 0.3027783891267705
# - Expected improvement: 0.13848969975384123
# - Actual improvement: 0.04580610613634206
# - (z = 0.3307546064274831)
#
# *** Iteration: 17 ***
# New cost: 0.3025133000605094
# - Expected improvement: 0.002041170480799271
# - Actual improvement: 0.00026508906626110385
# - (z = 0.12987110520886114)
#
# *** Iteration: 18 ***
# New cost: 0.30240507711179976
# - Expected improvement: 0.0013856895148549257
# - Actual improvement: 0.00010822294870965754
# - (z = 0.0781004312650716)
#
# *** Iteration: 19 ***
# New cost: 0.30232540932100055
# - Expected improvement: 0.0011655214081790837
# - Actual improvement: 7.966779079920938e-5
# - (z = 0.06835377732243965)
#
# *** Iteration: 20 ***
# New cost: 0.302269548700195
# - Expected improvement: 0.0009800952173789823
# - Actual improvement: 5.5860620805536776e-5
# - (z = 0.056995095797857206)
#
# *** Iteration: 21 ***
# New cost: 0.30222014819154736
# - Expected improvement: 0.0008610355335376324
# - Actual improvement: 4.940050864765677e-5
# - (z = 0.05737336814044234)
#
# *** Iteration: 22 ***
# New cost: 0.30218163500453077
# - Expected improvement: 0.0007429825179330167
# - Actual improvement: 3.851318701658668e-5
# - (z = 0.051835926266112796)
#
# *** Iteration: 23 ***
# New cost: 0.30214545922314806
# - Expected improvement: 0.0006595881403991662
# - Actual improvement: 3.617578138270794e-5
# - (z = 0.05484601551631184)
#
# *** Iteration: 24 ***
# New cost: 0.30211593840073625
# - Expected improvement: 0.0005742524217771596
# - Actual improvement: 2.952082241181042e-5
# - (z = 0.05140739732616412)
#
# *** Iteration: 25 ***
# New cost: 0.30208786743710264
# - Expected improvement: 0.0005111990166810924
# - Actual improvement: 2.8070963633608503e-5
# - (z = 0.05491200631772803)
#
# *** Iteration: 26 ***
# New cost: 0.30206445684180827
# - Expected improvement: 0.00044693797043709863
# - Actual improvement: 2.341059529437084e-5
# - (z = 0.05237996510226157)
#
# *** Iteration: 27 ***
# New cost: 0.3020422553595453
# - Expected improvement: 0.00039811336846201433
# - Actual improvement: 2.2201482262951266e-5
# - (z = 0.05576673385452918)
#
# *** Iteration: 28 ***
# New cost: 0.30202349976423387
# - Expected improvement: 0.00034898284491272845
# - Actual improvement: 1.8755595311448214e-5
# - (z = 0.05374360254338147)
#
# *** Iteration: 29 ***
# New cost: 0.3020058215567947
# - Expected improvement: 0.0003108739851867179
# - Actual improvement: 1.76782074391979e-5
# - (z = 0.056866152465539936)
#
# *** Iteration: 30 ***
# New cost: 0.30199074844514534
# - Expected improvement: 0.0002730465820559505
# - Actual improvement: 1.5073111649333004e-5
# - (z = 0.055203443807417235)
#
# *** Iteration: 31 ***
# New cost: 0.3019766305018517
# - Expected improvement: 0.0002432057466405668
# - Actual improvement: 1.4117943293645574e-5
# - (z = 0.058049382009506746)
#
# *** Iteration: 32 ***
# New cost: 0.30196450378989387
# - Expected improvement: 0.00021395735548581626
# - Actual improvement: 1.2126711957827219e-5
# - (z = 0.05667817276153952)
#
# *** Iteration: 33 ***
# New cost: 0.3019532098561316
# - Expected improvement: 0.00019054983692065602
# - Actual improvement: 1.1293933762257513e-5
# - (z = 0.059270235780680566)
#
# *** Iteration: 34 ***
# New cost: 0.3019434487252891
# - Expected improvement: 0.00016786425930406579
# - Actual improvement: 9.76113084250052e-6
# - (z = 0.05814895251060807)
#
# -----SOLVED-----
# eps criteria met at iteration: 34
#   4.661404 seconds (7.88 M allocations: 666.841 MiB, 6.57% gc time)

# %%
# U = zeros(m,convert(Int64,floor(tf/dt)))
# U[1,:] = 1
# X = rollout(x0,U,f,dt,tf)

plot((x0[1],x0[2]),marker=(:circle,"red"))
plot!((xf[1],xf[2]),marker=(:circle,"green"))
plot!(X[1,:],X[2,:], title="Dubins Car Parallel Park", color="blue",xlim=(-2,2),ylim=(-2,2))

# %%
W = plot(linspace(0,tf,size(X,2)),[U[1,1] U[1,:]']',title="Dubins Car Parallel Park")
W = plot!(linspace(0,tf,size(X,2)),[U[2,1] U[2,:]']',ylabel="Control")
