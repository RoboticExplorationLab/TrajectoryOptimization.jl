# %%
include("iLQR.jl")
using iLQR
using Plots
using RigidBodyDynamics
# Out:
# WARNING: replacing module iLQR

# %%
## Simple Pendulum
n = 2 # number of states 
m = 1 # number of controls

function fc(x,u)
    # continuous dynamics (as defined in https://github.com/HarvardAgileRoboticsLab/unscented-dynamic-programming/blob/master/pendulum_dynamics.m)
    m = 1.
    l = 0.5
    b = 0.1
    lc = 0.5
    I = 0.25
    g = 9.81
    return [x[2]; (u - m*g*lc*sin(x[1]) - b*x[2])];
end

#initial and goal conditions
x0 = [0.; 0.]
xf = [pi; 0.] # (ie, swing up)

Q = 1e-3eye(n)
Qf = 100.0*eye(n)
R = 1e-3*eye(m)

#simulation
dt = 0.1
tf = 5.0
pendulum = iLQR.Model(fc,n,m)
obj = iLQR.Objective(Q,R,Qf,tf,x0,xf)
solver = iLQR.Solver(pendulum,obj,iLQR.midpoint,dt=dt);

U = zeros(solver.model.m,solver.N-1
X_pendulum, U_pendulum = @time iLQR.solve(solver,U)
# Out:
# Initial Cost: 493.7220253622946
#
# *** Iteration: 1 ***
# New cost: 121.24117854213817
# - Expected improvement: 616.5170316254263
# - Actual improvement: 372.4808468201564
# - (z = 0.6041695974531689)
#
# *** Iteration: 2 ***
# New cost: 31.446906114889718
# - Expected improvement: 151.010075399863
# - Actual improvement: 89.79427242724846
# - (z = 0.5946243797937334)
#
# *** Iteration: 3 ***
# New cost: 8.23846095423271
# - Expected improvement: 38.81798826312459
# - Actual improvement: 23.208445160657007
# - (z = 0.5978786175970903)
#
# *** Iteration: 4 ***
# New cost: 2.328336076316915
# - Expected improvement: 9.845711691682288
# - Actual improvement: 5.910124877915795
# - (z = 0.6002740140063924)
#
# *** Iteration: 5 ***
# New cost: 0.8328178307207466
# - Expected improvement: 2.484442092134481
# - Actual improvement: 1.4955182455961686
# - (z = 0.6019533521553366)
#
# *** Iteration: 6 ***
# New cost: 0.4504376580294458
# - Expected improvement: 0.6320635090716233
# - Actual improvement: 0.38238017269130076
# - (z = 0.6049711258492708)
#
# *** Iteration: 7 ***
# New cost: 0.34885957137240614
# - Expected improvement: 0.16572547107117797
# - Actual improvement: 0.10157808665703966
# - (z = 0.6129298411432034)
#
# *** Iteration: 8 ***
# New cost: 0.3189405212078418
# - Expected improvement: 0.04723652923197118
# - Actual improvement: 0.029919050164564365
# - (z = 0.6333879870308974)
#
# *** Iteration: 9 ***
# New cost: 0.3079066004354763
# - Expected improvement: 0.01634710443298951
# - Actual improvement: 0.01103392077236548
# - (z = 0.6749770772919463)
#
# *** Iteration: 10 ***
# New cost: 0.2979231909436484
# - Expected improvement: 0.018606846139906562
# - Actual improvement: 0.00998340949182791
# - (z = 0.5365449586008155)
#
# *** Iteration: 11 ***
# New cost: 0.29225414270074124
# - Expected improvement: 0.008946270813082108
# - Actual improvement: 0.005669048242907149
# - (z = 0.6336772451172967)
#
# *** Iteration: 12 ***
# New cost: 0.28795458178582684
# - Expected improvement: 0.006613311186086032
# - Actual improvement: 0.004299560914914402
# - (z = 0.6501373962199741)
#
# *** Iteration: 13 ***
# New cost: 0.2844082147986934
# - Expected improvement: 0.005361807216684542
# - Actual improvement: 0.0035463669871334536
# - (z = 0.661412625224213)
#
# *** Iteration: 14 ***
# New cost: 0.2812887133692972
# - Expected improvement: 0.0046501935799147034
# - Actual improvement: 0.0031195014293961543
# - (z = 0.6708325956300025)
#
# *** Iteration: 15 ***
# New cost: 0.27839094576888185
# - Expected improvement: 0.004266513020109977
# - Actual improvement: 0.0028977676004153796
# - (z = 0.6791887395530988)
#
# *** Iteration: 16 ***
# New cost: 0.2755686185404398
# - Expected improvement: 0.004109148542210795
# - Actual improvement: 0.0028223272284420564
# - (z = 0.6868399132934713)
#
# *** Iteration: 17 ***
# New cost: 0.27270440995543843
# - Expected improvement: 0.004128354685583698
# - Actual improvement: 0.00286420858500136
# - (z = 0.6937893672273937)
#
# *** Iteration: 18 ***
# New cost: 0.2696962993558254
# - Expected improvement: 0.004298654204511484
# - Actual improvement: 0.003008110599613034
# - (z = 0.6997796185736432)
#
# *** Iteration: 19 ***
# New cost: 0.2664548738556211
# - Expected improvement: 0.004602316679970534
# - Actual improvement: 0.003241425500204287
# - (z = 0.7043030120702254)
#
# *** Iteration: 20 ***
# New cost: 0.2629119264585765
# - Expected improvement: 0.0050137688939278936
# - Actual improvement: 0.003542947397044638
# - (z = 0.7066435394211035)
#
# *** Iteration: 21 ***
# New cost: 0.25904144577815374
# - Expected improvement: 0.005481990667807118
# - Actual improvement: 0.0038704806804227276
# - (z = 0.7060356200808676)
#
# *** Iteration: 22 ***
# New cost: 0.25488825287579725
# - Expected improvement: 0.005916211764284469
# - Actual improvement: 0.004153192902356495
# - (z = 0.7020020695386314)
#
# *** Iteration: 23 ***
# New cost: 0.25058656032831433
# - Expected improvement: 0.006191490059220178
# - Actual improvement: 0.004301692547482916
# - (z = 0.6947750067169964)
#
# *** Iteration: 24 ***
# New cost: 0.246342987415181
# - Expected improvement: 0.006190731859894601
# - Actual improvement: 0.004243572913133348
# - (z = 0.6854719295184585)
#
# *** Iteration: 25 ***
# New cost: 0.24237751381362077
# - Expected improvement: 0.00586828813632812
# - Actual improvement: 0.0039654736015602154
# - (z = 0.6757462328769485)
#
# *** Iteration: 26 ***
# New cost: 0.23885419019131648
# - Expected improvement: 0.00528140778327423
# - Actual improvement: 0.0035233236223042863
# - (z = 0.6671182697655638)
#
# *** Iteration: 27 ***
# New cost: 0.23584485769345803
# - Expected improvement: 0.004556038472627462
# - Actual improvement: 0.0030093324978584524
# - (z = 0.6605151637630869)
#
# *** Iteration: 28 ***
# New cost: 0.23333766647847615
# - Expected improvement: 0.00382051103519447
# - Actual improvement: 0.0025071912149818854
# - (z = 0.6562449870935304)
#
# *** Iteration: 29 ***
# New cost: 0.2312694949316988
# - Expected improvement: 0.003161293883989262
# - Actual improvement: 0.002068171546777353
# - (z = 0.6542167930833153)
#
# *** Iteration: 30 ***
# New cost: 0.22955778163134982
# - Expected improvement: 0.0026166321917800084
# - Actual improvement: 0.0017117133003489715
# - (z = 0.6541665678983142)
#
# *** Iteration: 31 ***
# New cost: 0.22812080489439396
# - Expected improvement: 0.002191189296651444
# - Actual improvement: 0.001436976736955864
# - (z = 0.6557976251307174)
#
# *** Iteration: 32 ***
# New cost: 0.22688667883063096
# - Expected improvement: 0.0018731621813861971
# - Actual improvement: 0.001234126063762997
# - (z = 0.6588463487180304)
#
# *** Iteration: 33 ***
# New cost: 0.22579514683152344
# - Expected improvement: 0.001646091137224177
# - Actual improvement: 0.0010915319991075256
# - (z = 0.6631054468516178)
#
# *** Iteration: 34 ***
# New cost: 0.22479579187177098
# - Expected improvement: 0.0014950851901723815
# - Actual improvement: 0.000999354959752452
# - (z = 0.6684267667966316)
#
# -----SOLVED-----
# eps criteria met at iteration: 34
#   0.305289 seconds (1.08 M allocations: 60.427 MiB, 4.37% gc time)
# ([0.0 -0.0104547 … 3.14101 3.14156; 0.0 -0.208049 … 0.0113278 1.31093e-5], [-2.09095 -1.77786 … -0.1125 6.93757e-310])

# %%
P = plot(linspace(0,tf,solver.N),X_pendulum[1,:],label="theta")
P = plot!(linspace(0,tf,solver.N),X_pendulum[2,:],label="theta_dot",title="Pendulum",ylabel="states")

# %%
## Double pendulum
urdf_dp = "urdf/doublependulum.urdf"
dp = iLQR.Model(urdf_dp)

# initial and goal states
x0 = [0.;0.;0.;0.]
xf = [pi;0.;0.;0.]

# costs
Q = 0.0001*eye(4)
Qf = 250.0*eye(4)
R = 0.0001*eye(2)

# simulation
tf = 5.0
dt = 0.1

obj = iLQR.Objective(Q,R,Qf,tf,x0,xf)
solver = iLQR.Solver(dp,obj,dt=dt);

U = 10.0*rand(solver.model.m,solver.N)
X_dp, U_dp = @time iLQR.solve(solver,U);
# Out:
# Initial Cost: 2098.1920163677783
#
# *** Iteration: 1 ***
# New cost: 1149.985604267515
# - Expected improvement: 1180.049191458961
# - Actual improvement: 948.2064121002632
# - (z = 0.8035312586655327)
#
# *** Iteration: 2 ***
# New cost: 625.5024276561087
# - Expected improvement: 646.7414745877666
# - Actual improvement: 524.4831766114064
# - (z = 0.8109626446111444)
#
# *** Iteration: 3 ***
# New cost: 362.94200769054896
# - Expected improvement: 351.75305798376337
# - Actual improvement: 262.56041996555973
# - (z = 0.7464339371221026)
#
# *** Iteration: 4 ***
# New cost: 220.13806248935666
# - Expected improvement: 204.0760027258106
# - Actual improvement: 142.8039452011923
# - (z = 0.6997586354778749)
#
# *** Iteration: 5 ***
# New cost: 133.46080002291026
# - Expected improvement: 123.75697954354158
# - Actual improvement: 86.6772624664464
# - (z = 0.7003828211236411)
#
# *** Iteration: 6 ***
# New cost: 79.17925977065887
# - Expected improvement: 75.00382593093212
# - Actual improvement: 54.28154025225139
# - (z = 0.7237169514824081)
#
# *** Iteration: 7 ***
# New cost: 24.823489970038587
# - Expected improvement: 98.82458201678976
# - Actual improvement: 54.35576980062029
# - (z = 0.5500227644917894)
#
# *** Iteration: 8 ***
# New cost: 6.598540575801781
# - Expected improvement: 30.879869349810104
# - Actual improvement: 18.224949394236805
# - (z = 0.5901886820757835)
#
# *** Iteration: 9 ***
# New cost: 1.7779109159435427
# - Expected improvement: 8.099248367668677
# - Actual improvement: 4.8206296598582385
# - (z = 0.595194694744968)
#
# *** Iteration: 10 ***
# New cost: 0.5419802622296768
# - Expected improvement: 2.07418292050601
# - Actual improvement: 1.235930653713866
# - (z = 0.5958638659566018)
#
# *** Iteration: 11 ***
# New cost: 0.22629363591418206
# - Expected improvement: 0.5301098231666921
# - Actual improvement: 0.3156866263154947
# - (z = 0.5955117459052021)
#
# *** Iteration: 12 ***
# New cost: 0.14507055115001002
# - Expected improvement: 0.1365374444504258
# - Actual improvement: 0.08122308476417203
# - (z = 0.5948777281653505)
#
# *** Iteration: 13 ***
# New cost: 0.1234164927514604
# - Expected improvement: 0.03630015735911522
# - Actual improvement: 0.021654058398549628
# - (z = 0.5965279484694064)
#
# *** Iteration: 14 ***
# New cost: 0.11688587293032075
# - Expected improvement: 0.010729716283331091
# - Actual improvement: 0.006530619821139644
# - (z = 0.6086479501126363)
#
# *** Iteration: 15 ***
# New cost: 0.11430247790286749
# - Expected improvement: 0.004056215953700338
# - Actual improvement: 0.002583395027453264
# - (z = 0.6368978025187557)
#
# *** Iteration: 16 ***
# New cost: 0.11296471464111627
# - Expected improvement: 0.002026177465689111
# - Actual improvement: 0.0013377632617512236
# - (z = 0.6602399268596372)
#
# *** Iteration: 17 ***
# New cost: 0.11222424143787492
# - Expected improvement: 0.0011119109513958276
# - Actual improvement: 0.0007404732032413458
# - (z = 0.6659464971649027)
#
# -----SOLVED-----
# eps criteria met at iteration: 17
#  46.066686 seconds (54.34 M allocations: 3.265 GiB, 3.31% gc time)

# %%
P = plot(linspace(0,tf,solver.N),X_dp[1,:],title="Double Pendulum",label="theta")
P = plot!(linspace(0,tf,solver.N),X_dp[2,:],ylabel="State",label="theta_dot")

# %%
vis = MechanismVisualizer(parse_urdf(Float64,urdf_dp),URDFVisuals(urdf_dp));
IJuliaCell(vis)

state = MechanismState(parse_urdf(Float64,urdf_dp))
for i = 1:size(X_dp,2)
    set_configuration!(state, X_dp[1:2,i])
    set_configuration!(vis, configuration(state))
    sleep(0.1)
end
